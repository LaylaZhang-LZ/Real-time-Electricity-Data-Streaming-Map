# %%
from openelectricity import AsyncOEClient
from openelectricity.types import DataMetric, MarketMetric, UnitStatusType
from datetime import datetime, timedelta
import paho.mqtt.client as mqtt
import json
import time
import pandas as pd
import asyncio
import re
import os
import pickle
import os
import json
from datetime import datetime, timedelta
from collections import Counter

# OpenElectricity API
from openelectricity import AsyncOEClient
from openelectricity.types import DataMetric, MarketMetric, UnitStatusType
from datetime import datetime, timedelta

# Async support
import asyncio
import nest_asyncio
nest_asyncio.apply()

# Optional: Suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Data Retrieval

# %%
# Define data fetching function
async def fetch_data_in_chunks(client, facility_codes, start_date, end_date, max_days=7, batch_size=10):
    """
    Args:
        client: AsyncOEClient instance
        facility_codes: List of facility codes to fetch data for
        start_date: Start date for data retrieval
        end_date: End date for data retrieval
        max_days: Maximum days per chunk (default 7 to stay within 8-day limit)
        batch_size: Number of facilities to fetch at once (reduced to 10)
    
    Returns:
        all_facility_data: List of facility power and emissions data
        all_market_data: List of market price and demand data
    """
    all_facility_data = []
    all_market_data = []
    market_data_fetched = False
    
    # Split facilities into batches
    total_facilities = len(facility_codes)
    num_batches = (total_facilities + batch_size - 1) // batch_size
    
    print(f"Total facilities: {total_facilities}")
    print(f"Batch size: {batch_size}")
    print(f"Number of batches: {num_batches}")
    print()
    
    for batch_idx in range(num_batches):
        start_idx = batch_idx * batch_size
        end_idx = min((batch_idx + 1) * batch_size, total_facilities)
        facility_batch = facility_codes[start_idx:end_idx]
        
        print(f"Processing batch {batch_idx + 1}/{num_batches} ({len(facility_batch)} facilities)")
        
        current_start = start_date
        
        while current_start < end_date:
            # Calculate end date for current time chunk
            current_end = min(current_start + timedelta(days=max_days), end_date)
            
            print(f"  Fetching data from {current_start.date()} to {current_end.date()}")
            
            try:
                # 1. Fetch facility data (power and emissions)
                facility_response = await client.get_facility_data(
                    network_code="NEM",
                    facility_code=facility_batch,  # Batch of facilities
                    metrics=[DataMetric.POWER, DataMetric.EMISSIONS],
                    interval="5m",
                    date_start=current_start,
                    date_end=current_end
                )
                
                # Process facility data - FIXED attribute access
                for series in facility_response.data:
                    metric_name = series.metric
                    unit = series.unit
                    
                    for result in series.results:
                        # Extract facility code from the result name
                        # The name format may vary, try to extract facility code
                        facility_name = result.name
                        
                        for point in result.data:
                            all_facility_data.append({
                                'timestamp': point.timestamp,
                                'facility_name': facility_name,
                                'metric': metric_name,
                                'value': point.value,
                                'unit': unit
                            })
                
                print(f"    ✓ Fetched {len(facility_response.data)} facility metric series")
                
            except Exception as e:
                print(f"    ! Error fetching facility data: {e}")
                # Continue with next batch instead of breaking completely
            
            # Fetch market data only once (not per facility batch)
            if not market_data_fetched:
                try:
                    # 2. Fetch market data (price and demand)
                    market_response = await client.get_market(
                        network_code="NEM",
                        metrics=[MarketMetric.PRICE, MarketMetric.DEMAND],
                        interval="5m",
                        date_start=current_start,
                        date_end=current_end,
                        primary_grouping="network_region"
                    )
                    
                    # Process market data
                    for series in market_response.data:
                        for result in series.results:
                            region = result.name.split("_")[-1] if "_" in result.name else result.name
                            for point in result.data:
                                all_market_data.append({
                                    'timestamp': point.timestamp,
                                    'region': region,
                                    'metric': series.metric,
                                    'value': point.value,
                                    'unit': series.unit
                                })
                    
                    print(f"    Fetched {len(market_response.data)} market metric series")
                    
                except Exception as e:
                    print(f"    Error fetching market data: {e}")
            
            # Move to next time chunk
            current_start = current_end + timedelta(minutes=5)
            
            # Add small delay to avoid API rate limiting
            await asyncio.sleep(0.5)
        
        # Mark market data as fetched after first batch's time chunks are done
        market_data_fetched = True
        
        # Delay between facility batches
        if batch_idx < num_batches - 1:
            print(f"  Waiting before next batch...")
            await asyncio.sleep(1)
        
        print()
    
    return all_facility_data, all_market_data

# %%
# Fetch list of operational facilities in NEM network
async with AsyncOEClient() as client:
    facilities_response = await client.get_facilities(
        network_id=["NEM"],
        status_id=[UnitStatusType.OPERATING]
    )
    
    # Extract facility codes
    facility_codes = [facility.code for facility in facilities_response.data]
    
    print(f"Found {len(facility_codes)} operational facilities")
    print(f"Sample facilities: {facility_codes[:5]}")
# Out:
# [2025-11-06 12:34:14] DEBUG [openelectricity.client.__init__:79] Initialized client with base URL: https://api.openelectricity.org.au/v4/
# [2025-11-06 12:34:14] DEBUG [openelectricity.client.__init__:417] Initialized asynchronous client
# [2025-11-06 12:34:14] DEBUG [openelectricity.client._ensure_client:422] Creating new async client session
# [2025-11-06 12:34:14] DEBUG [openelectricity.client.get_facilities:450] Getting facilities
# [2025-11-06 12:34:14] DEBUG [openelectricity.client.get_facilities:461] Request parameters: {'status_id': ['operating'], 'network_id': ['NEM']}
# [2025-11-06 12:34:15] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
# Found 420 operational facilities
# Sample facilities: ['ADP', 'ALDGASF', 'ANGASTON', 'APPIN', 'ARWF']
# [2025-11-06 12:34:15] DEBUG [openelectricity.client.close:600] Closing async client session

# %%
# Set time range (at least 1 week in October 2025)
start_date = datetime(2025, 10, 1, 0, 0, 0)
end_date = datetime(2025, 10, 8, 23, 55, 0)  # 8 days of data

print(f"Start time: {start_date}")
print(f"End time: {end_date}")
print(f"Data interval: 5 minutes")
print(f"Time span: {(end_date - start_date).days} days")
# Out:
# Start time: 2025-10-01 00:00:00
# End time: 2025-10-08 23:55:00
# Data interval: 5 minutes
# Time span: 7 days

# %%
# Fetch facility and market data with smaller batches
async with AsyncOEClient() as client:
    facility_data, market_data = await fetch_data_in_chunks(
        client, 
        facility_codes,
        start_date, 
        end_date,
        max_days=7,  # Stay within 8-day limit
        batch_size=10  # Reduced batch size to avoid errors
    )

print(f"\nTotal facility data records fetched: {len(facility_data)}")
print(f"Total market data records fetched: {len(market_data)}")
# Out:
# [2025-11-06 12:34:17] DEBUG [openelectricity.client.__init__:79] Initialized client with base URL: https://api.openelectricity.org.au/v4/
# [2025-11-06 12:34:17] DEBUG [openelectricity.client.__init__:417] Initialized asynchronous client
# [2025-11-06 12:34:17] DEBUG [openelectricity.client._ensure_client:422] Creating new async client session
# Total facilities: 420
# Batch size: 10
# Number of batches: 42
#
# Processing batch 1/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:34:17] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['ADP', 'ALDGASF', 'ANGASTON', 'APPIN', 'ARWF', 'AVLSF', 'DEIBDL', 'BAKING', 'BHWF', 'BALBESS'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:17] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['ADP', 'ALDGASF', 'ANGASTON', 'APPIN', 'ARWF', 'AVLSF', 'DEIBDL', 'BAKING', 'BHWF', 'BALBESS'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:34:18] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
# [2025-11-06 12:34:19] DEBUG [openelectricity.client.get_market:567] Getting market data for NEM (metrics: [<MarketMetric.PRICE: 'price'>, <MarketMetric.DEMAND: 'demand'>], interval: 5m)
# [2025-11-06 12:34:19] DEBUG [openelectricity.client.get_market:583] Request parameters: {'metrics': ['price', 'demand'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00', 'primary_grouping': 'network_region'}
# [2025-11-06 12:34:19] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     Fetched 2 market metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:34:20] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['ADP', 'ALDGASF', 'ANGASTON', 'APPIN', 'ARWF', 'AVLSF', 'DEIBDL', 'BAKING', 'BHWF', 'BALBESS'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:20] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['ADP', 'ALDGASF', 'ANGASTON', 'APPIN', 'ARWF', 'AVLSF', 'DEIBDL', 'BAKING', 'BHWF', 'BALBESS'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:34:21] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
# [2025-11-06 12:34:21] DEBUG [openelectricity.client.get_market:567] Getting market data for NEM (metrics: [<MarketMetric.PRICE: 'price'>, <MarketMetric.DEMAND: 'demand'>], interval: 5m)
# [2025-11-06 12:34:21] DEBUG [openelectricity.client.get_market:583] Request parameters: {'metrics': ['price', 'demand'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00', 'primary_grouping': 'network_region'}
# [2025-11-06 12:34:21] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     Fetched 2 market metric series
#   Waiting before next batch...
#
# Processing batch 2/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:34:23] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['BANGOWF', 'BAPS', 'BANNSP', 'BARCALDN', 'BARCSF', 'BARKIPS', 'BARRON', 'BASTYAN', 'BAYSW', 'BBP31'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:23] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['BANGOWF', 'BAPS', 'BANNSP', 'BARCALDN', 'BARCSF', 'BARKIPS', 'BARRON', 'BASTYAN', 'BAYSW', 'BBP31'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:34:24] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:34:25] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['BANGOWF', 'BAPS', 'BANNSP', 'BARCALDN', 'BARCSF', 'BARKIPS', 'BARRON', 'BASTYAN', 'BAYSW', 'BBP31'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:25] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['BANGOWF', 'BAPS', 'BANNSP', 'BARCALDN', 'BARCSF', 'BARKIPS', 'BARRON', 'BASTYAN', 'BAYSW', 'BBP31'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:34:25] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 3/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:34:27] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['BRYB1WF1', 'BERWICK', 'BERYLSF', 'BIALAWF', 'BLAYNEY', 'SNOWY6', 'BLUEGSF', 'BLYTHB', 'BOCOROCK', 'BODWF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:27] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['BRYB1WF1', 'BERWICK', 'BERYLSF', 'BIALAWF', 'BLAYNEY', 'SNOWY6', 'BLUEGSF', 'BLYTHB', 'BOCOROCK', 'BODWF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:34:28] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:34:28] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['BRYB1WF1', 'BERWICK', 'BERYLSF', 'BIALAWF', 'BLAYNEY', 'SNOWY6', 'BLUEGSF', 'BLYTHB', 'BOCOROCK', 'BODWF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:28] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['BRYB1WF1', 'BERWICK', 'BERYLSF', 'BIALAWF', 'BLAYNEY', 'SNOWY6', 'BLUEGSF', 'BLYTHB', 'BOCOROCK', 'BODWF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:34:29] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 4/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:34:31] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['MCKAY', 'BOLIVAR', 'BOLIVPS', 'BOMENSF', 'BBATTERY', 'BRAEMARA', 'B2PS', 'BRNDBES', 'BWTR1', 'BHILLGT'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:31] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['MCKAY', 'BOLIVAR', 'BOLIVPS', 'BOMENSF', 'BBATTERY', 'BRAEMARA', 'B2PS', 'BRNDBES', 'BWTR1', 'BHILLGT'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:34:31] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:34:32] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['MCKAY', 'BOLIVAR', 'BOLIVPS', 'BOMENSF', 'BBATTERY', 'BRAEMARA', 'B2PS', 'BRNDBES', 'BWTR1', 'BHILLGT'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:32] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['MCKAY', 'BOLIVAR', 'BOLIVPS', 'BOMENSF', 'BBATTERY', 'BRAEMARA', 'B2PS', 'BRNDBES', 'BWTR1', 'BHILLGT'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:34:33] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 5/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:34:34] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['BROKENH', 'BHB', 'BROOKLYN', 'BROWNMT', 'BPLANDF', 'BULGANA', 'BNGSF1', 'BNGSF2', 'BDONGHYD', 'BURRIN'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:34] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['BROKENH', 'BHB', 'BROOKLYN', 'BROWNMT', 'BPLANDF', 'BULGANA', 'BNGSF1', 'BNGSF2', 'BDONGHYD', 'BURRIN'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:34:35] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:34:36] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['BROKENH', 'BHB', 'BROOKLYN', 'BROWNMT', 'BPLANDF', 'BULGANA', 'BNGSF1', 'BNGSF2', 'BDONGHYD', 'BURRIN'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:36] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['BROKENH', 'BHB', 'BROOKLYN', 'BROWNMT', 'BPLANDF', 'BULGANA', 'BNGSF1', 'BNGSF2', 'BDONGHYD', 'BURRIN'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:34:37] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 6/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:34:38] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['BUTLERSG', 'CALL_B', 'CALLIDEC1', 'CANUNDA1', 'CAPBES', 'CAPTL_WF', 'CESF', 'LI_WY_CA', 'CATHROCK', 'CTHLWF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:38] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['BUTLERSG', 'CALL_B', 'CALLIDEC1', 'CANUNDA1', 'CAPBES', 'CAPTL_WF', 'CESF', 'LI_WY_CA', 'CATHROCK', 'CTHLWF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:34:39] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:34:40] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['BUTLERSG', 'CALL_B', 'CALLIDEC1', 'CANUNDA1', 'CAPBES', 'CAPTL_WF', 'CESF', 'LI_WY_CA', 'CATHROCK', 'CTHLWF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:40] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['BUTLERSG', 'CALL_B', 'CALLIDEC1', 'CANUNDA1', 'CAPBES', 'CAPTL_WF', 'CESF', 'LI_WY_CA', 'CATHROCK', 'CTHLWF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:34:40] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 7/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:34:42] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['CETHANA', 'CHALLWF', 'CHPSTWF', 'CHYTWF', 'CHILDSF', 'CHBESS', 'CBWWBA', 'CLARESF', 'CLRKCWF', 'CLAYTON'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:42] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['CETHANA', 'CHALLWF', 'CHPSTWF', 'CHYTWF', 'CHILDSF', 'CHBESS', 'CBWWBA', 'CLARESF', 'CLRKCWF', 'CLAYTON'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:34:42] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:34:43] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['CETHANA', 'CHALLWF', 'CHPSTWF', 'CHYTWF', 'CHILDSF', 'CHBESS', 'CBWWBA', 'CLARESF', 'CLRKCWF', 'CLAYTON'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:43] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['CETHANA', 'CHALLWF', 'CHPSTWF', 'CHYTWF', 'CHILDSF', 'CHBESS', 'CBWWBA', 'CLARESF', 'CLRKCWF', 'CLAYTON'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:34:43] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 8/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:34:45] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['CLEMGPWF', 'CLERMSF', 'CLOVER', 'CLUNY', 'CODRGTON', 'COHUNSF1', 'COLEASF', 'COLWF01', 'CSPVPS', 'COLONGRA'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:45] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['CLEMGPWF', 'CLERMSF', 'CLOVER', 'CLUNY', 'CODRGTON', 'COHUNSF1', 'COLEASF', 'COLWF01', 'CSPVPS', 'COLONGRA'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:34:46] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:34:47] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['CLEMGPWF', 'CLERMSF', 'CLOVER', 'CLUNY', 'CODRGTON', 'COHUNSF1', 'COLEASF', 'COLWF01', 'CSPVPS', 'COLONGRA'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:47] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['CLEMGPWF', 'CLERMSF', 'CLOVER', 'CLUNY', 'CODRGTON', 'COHUNSF1', 'COLEASF', 'COLWF01', 'CSPVPS', 'COLONGRA'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:34:47] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 9/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:34:49] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['COLUMSF', 'CPSA', 'CONDONG1', 'CBWF', 'COOPGWF', 'COPTNHYD', 'CRWASF1', 'CROOKWEL', 'CROOKWF2', 'CROOKWF3'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:49] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['COLUMSF', 'CPSA', 'CONDONG1', 'CBWF', 'COOPGWF', 'COPTNHYD', 'CRWASF1', 'CROOKWEL', 'CROOKWF2', 'CROOKWF3'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:34:50] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:34:51] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['COLUMSF', 'CPSA', 'CONDONG1', 'CBWF', 'COOPGWF', 'COPTNHYD', 'CRWASF1', 'CROOKWEL', 'CROOKWF2', 'CROOKWF3'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:51] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['COLUMSF', 'CPSA', 'CONDONG1', 'CBWF', 'COOPGWF', 'COPTNHYD', 'CRWASF1', 'CROOKWEL', 'CROOKWF2', 'CROOKWF3'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:34:51] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 10/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:34:53] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['CROWLWF', 'CRURWF1', 'CULCSF', 'CULLERIN', 'DALNTH', 'DDPS1', 'DDSF', 'DARLSF', 'DPNTB', 'DARTM'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:53] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['CROWLWF', 'CRURWF1', 'CULCSF', 'CULLERIN', 'DALNTH', 'DDPS1', 'DDSF', 'DARLSF', 'DPNTB', 'DARTM'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:34:53] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:34:54] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['CROWLWF', 'CRURWF1', 'CULCSF', 'CULLERIN', 'DALNTH', 'DDPS1', 'DDSF', 'DARLSF', 'DPNTB', 'DARTM'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:54] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['CROWLWF', 'CRURWF1', 'CULCSF', 'CULLERIN', 'DALNTH', 'DDPS1', 'DDSF', 'DARLSF', 'DPNTB', 'DARTM'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:34:55] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 11/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:34:56] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['DAYDSF', 'DEVILS_G', 'DIAPURWF', 'DRYCGT', 'DULAWF', 'DUNDWF', 'EASTCRK', 'EASTCRK2', 'EDENVSF', 'EILDON'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:56] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['DAYDSF', 'DEVILS_G', 'DIAPURWF', 'DRYCGT', 'DULAWF', 'DUNDWF', 'EASTCRK', 'EASTCRK2', 'EDENVSF', 'EILDON'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:34:57] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:34:58] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['DAYDSF', 'DEVILS_G', 'DIAPURWF', 'DRYCGT', 'DULAWF', 'DUNDWF', 'EASTCRK', 'EASTCRK2', 'EDENVSF', 'EILDON'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:34:58] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['DAYDSF', 'DEVILS_G', 'DIAPURWF', 'DRYCGT', 'DULAWF', 'DUNDWF', 'EASTCRK', 'EASTCRK2', 'EDENVSF', 'EILDON'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:34:58] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 12/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:35:00] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['EILDONPD', 'ELAINEWF', 'EMERASF', 'ERARING', 'ERB', 'ERGT01', 'FWF', 'FINLEYSF', 'FISHER', 'FLYCRKWF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:00] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['EILDONPD', 'ELAINEWF', 'EMERASF', 'ERARING', 'ERB', 'ERGT01', 'FWF', 'FINLEYSF', 'FISHER', 'FLYCRKWF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:35:01] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:35:01] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['EILDONPD', 'ELAINEWF', 'EMERASF', 'ERARING', 'ERB', 'ERGT01', 'FWF', 'FINLEYSF', 'FISHER', 'FLYCRKWF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:01] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['EILDONPD', 'ELAINEWF', 'EMERASF', 'ERARING', 'ERB', 'ERGT01', 'FWF', 'FINLEYSF', 'FISHER', 'FLYCRKWF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:35:02] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 13/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:35:04] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['GANGARR', 'GANNBESS', 'GANNSF', 'GERMCRK', 'GIRGSF', 'GSTONE', 'GLBWNHYD', 'GLENMAGG', 'GLENNCRK', 'GLENSF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:04] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['GANGARR', 'GANNBESS', 'GANNSF', 'GERMCRK', 'GIRGSF', 'GSTONE', 'GLBWNHYD', 'GLENMAGG', 'GLENNCRK', 'GLENSF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:35:05] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:35:05] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['GANGARR', 'GANNBESS', 'GANNSF', 'GERMCRK', 'GIRGSF', 'GSTONE', 'GLBWNHYD', 'GLENMAGG', 'GLENNCRK', 'GLENSF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:05] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['GANGARR', 'GANNBESS', 'GANNSF', 'GERMCRK', 'GIRGSF', 'GSTONE', 'GLBWNHYD', 'GLENMAGG', 'GLENNCRK', 'GLENSF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:35:06] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 14/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:35:08] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['GLRWNSF', 'GPWFEST', 'GOONUMSF', 'GOESF1', 'GORDON', 'GSWF', 'GRANGEAV', 'GRANWF', 'GREENB', 'GRIFSF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:08] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['GLRWNSF', 'GPWFEST', 'GOONUMSF', 'GOESF1', 'GORDON', 'GSWF', 'GRANGEAV', 'GRANWF', 'GREENB', 'GRIFSF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:35:08] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:35:09] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['GLRWNSF', 'GPWFEST', 'GOONUMSF', 'GOESF1', 'GORDON', 'GSWF', 'GRANGEAV', 'GRANWF', 'GREENB', 'GRIFSF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:09] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['GLRWNSF', 'GPWFEST', 'GOONUMSF', 'GOESF1', 'GORDON', 'GSWF', 'GRANGEAV', 'GRANWF', 'GREENB', 'GRIFSF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:35:10] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 15/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:35:11] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['GROSV1', 'GROSV2', 'GULLRGWF', 'GNNDHSF', 'GUNNING', 'SNOWY3', 'HLMSEW01', 'HALAMRD', 'AGLHAL', 'HALLWF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:11] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['GROSV1', 'GROSV2', 'GULLRGWF', 'GNNDHSF', 'GUNNING', 'SNOWY3', 'HLMSEW01', 'HALAMRD', 'AGLHAL', 'HALLWF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:35:12] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:35:13] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['GROSV1', 'GROSV2', 'GULLRGWF', 'GNNDHSF', 'GUNNING', 'SNOWY3', 'HLMSEW01', 'HALAMRD', 'AGLHAL', 'HALLWF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:13] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['GROSV1', 'GROSV2', 'GULLRGWF', 'GNNDHSF', 'GUNNING', 'SNOWY3', 'HLMSEW01', 'HALAMRD', 'AGLHAL', 'HALLWF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:35:13] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 16/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:35:15] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['HALLWF2', 'HAMISF', 'HAMPTON', 'HVWW', 'HASTING', 'HAUGHT1', 'HD1WF', 'HAYMSF', 'HBESS', 'HEPWIND'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:15] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['HALLWF2', 'HAMISF', 'HAMPTON', 'HVWW', 'HASTING', 'HAUGHT1', 'HD1WF', 'HAYMSF', 'HBESS', 'HEPWIND'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:35:16] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:35:16] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['HALLWF2', 'HAMISF', 'HAMPTON', 'HVWW', 'HASTING', 'HAUGHT1', 'HD1WF', 'HAYMSF', 'HBESS', 'HEPWIND'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:16] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['HALLWF2', 'HAMISF', 'HAMPTON', 'HVWW', 'HASTING', 'HAUGHT1', 'HD1WF', 'HAYMSF', 'HBESS', 'HEPWIND'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:35:17] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 17/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:35:19] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['HILLSTN', 'HORNSDAL', 'HORNSDAL2', 'HORNSDAL3', 'HORNSDPR', 'HUGSF', 'HUMENSW', 'HUMEV', 'HUNTER', 'HEZ'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:19] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['HILLSTN', 'HORNSDAL', 'HORNSDAL2', 'HORNSDAL3', 'HORNSDPR', 'HUGSF', 'HUMENSW', 'HUMEV', 'HUNTER', 'HEZ'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:35:20] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:35:21] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['HILLSTN', 'HORNSDAL', 'HORNSDAL2', 'HORNSDAL3', 'HORNSDPR', 'HUGSF', 'HUMENSW', 'HUMEV', 'HUNTER', 'HEZ'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:21] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['HILLSTN', 'HORNSDAL', 'HORNSDAL2', 'HORNSDAL3', 'HORNSDPR', 'HUGSF', 'HUMENSW', 'HUMEV', 'HUNTER', 'HEZ'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:35:21] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 18/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:35:23] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['INVICTA', 'ICSM', 'JACKSGUL', 'JEERA', 'JEERB', 'JEMALNG1', 'JNDSHPS', 'SNWYGJP2', 'JBUTTERS', 'JOUNAMA'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:23] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['INVICTA', 'ICSM', 'JACKSGUL', 'JEERA', 'JEERB', 'JEMALNG1', 'JNDSHPS', 'SNWYGJP2', 'JBUTTERS', 'JOUNAMA'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:35:24] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:35:25] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['INVICTA', 'ICSM', 'JACKSGUL', 'JEERA', 'JEERB', 'JEMALNG1', 'JNDSHPS', 'SNWYGJP2', 'JBUTTERS', 'JOUNAMA'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:25] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['INVICTA', 'ICSM', 'JACKSGUL', 'JEERA', 'JEERB', 'JEMALNG1', 'JNDSHPS', 'SNWYGJP2', 'JBUTTERS', 'JOUNAMA'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:35:25] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 19/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:35:27] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['JUNEESF', 'KABANWF', 'KARSF', 'KAREEYA', 'KEEPIT', 'AGLSITA', 'KENNEDY', 'KERNGSP', 'KIAMSF1', 'KIATAWF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:27] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['JUNEESF', 'KABANWF', 'KARSF', 'KAREEYA', 'KEEPIT', 'AGLSITA', 'KENNEDY', 'KERNGSP', 'KIAMSF1', 'KIATAWF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:35:28] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:35:28] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['JUNEESF', 'KABANWF', 'KARSF', 'KAREEYA', 'KEEPIT', 'AGLSITA', 'KENNEDY', 'KERNGSP', 'KIAMSF1', 'KIATAWF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:28] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['JUNEESF', 'KABANWF', 'KARSF', 'KAREEYA', 'KEEPIT', 'AGLSITA', 'KENNEDY', 'KERNGSP', 'KIAMSF1', 'KIATAWF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:35:29] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 20/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:35:31] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['KSP1', 'KINGASF', 'KOGANCK', 'KESS1', 'LADBROKE', 'LBBESS', 'LKBONNY1', 'LKBONNY_2', 'LKBONNY3', 'LK_ECHO'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:31] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['KSP1', 'KINGASF', 'KOGANCK', 'KESS1', 'LADBROKE', 'LBBESS', 'LKBONNY1', 'LKBONNY_2', 'LKBONNY3', 'LK_ECHO'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:35:31] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:35:32] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['KSP1', 'KINGASF', 'KOGANCK', 'KESS1', 'LADBROKE', 'LBBESS', 'LKBONNY1', 'LKBONNY_2', 'LKBONNY3', 'LK_ECHO'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:32] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['KSP1', 'KINGASF', 'KOGANCK', 'KESS1', 'LADBROKE', 'LBBESS', 'LKBONNY1', 'LKBONNY_2', 'LKBONNY3', 'LK_ECHO'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:35:33] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 21/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:35:35] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['LVES', 'LNGS', 'LEM_WIL', 'LILYVASF', 'LIMBESS', 'LIMOSF1', 'LIMOSF2', 'LGAPWF1', 'LONGFORD', 'LRSF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:35] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['LVES', 'LNGS', 'LEM_WIL', 'LILYVASF', 'LIMBESS', 'LIMOSF1', 'LIMOSF2', 'LGAPWF1', 'LONGFORD', 'LRSF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:35:35] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:35:36] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['LVES', 'LNGS', 'LEM_WIL', 'LILYVASF', 'LIMBESS', 'LIMOSF1', 'LIMOSF2', 'LGAPWF1', 'LONGFORD', 'LRSF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:36] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['LVES', 'LNGS', 'LEM_WIL', 'LILYVASF', 'LIMBESS', 'LIMOSF1', 'LIMOSF2', 'LGAPWF1', 'LONGFORD', 'LRSF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:35:36] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 22/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:35:38] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['LONSDALE', 'LOYYANGA', 'LOYYB', 'LUCASHGT', 'LUCAS2S2', 'MACARTH', 'MCINTYR', 'MACKAY', 'MACKNTSH', 'MANSLR'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:38] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['LONSDALE', 'LOYYANGA', 'LOYYB', 'LUCASHGT', 'LUCAS2S2', 'MACARTH', 'MCINTYR', 'MACKAY', 'MACKNTSH', 'MANSLR'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:35:39] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:35:40] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['LONSDALE', 'LOYYANGA', 'LOYYB', 'LUCASHGT', 'LUCAS2S2', 'MACARTH', 'MCINTYR', 'MACKAY', 'MACKNTSH', 'MANSLR'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:40] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['LONSDALE', 'LOYYANGA', 'LOYYB', 'LUCASHGT', 'LUCAS2S2', 'MACARTH', 'MCINTYR', 'MACKAY', 'MACKNTSH', 'MANSLR'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:35:40] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 23/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:35:42] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['MANNUMB', 'MANNSF', 'MAPS2', 'MAROOWF1', 'MARYRSF', 'MEADOWBK', '0MREH', '0MREHA2', 'MREHA3', 'METZSF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:42] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['MANNUMB', 'MANNSF', 'MAPS2', 'MAROOWF1', 'MARYRSF', 'MEADOWBK', '0MREH', '0MREHA2', 'MREHA3', 'METZSF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:35:42] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:35:43] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['MANNUMB', 'MANNSF', 'MAPS2', 'MAROOWF1', 'MARYRSF', 'MEADOWBK', '0MREH', '0MREHA2', 'MREHA3', 'METZSF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:43] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['MANNUMB', 'MANNSF', 'MAPS2', 'MAROOWF1', 'MARYRSF', 'MEADOWBK', '0MREH', '0MREHA2', 'MREHA3', 'METZSF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:35:44] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 24/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:35:45] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['MIDDLSF1', 'MIDLDPS', 'MILLMERN', 'MINTARO', 'MOKOSF', 'MOLNGSF1', 'MOORAWF1', 'MORANBAH', 'MBAHNTH', 'MOREESF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:45] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['MIDDLSF1', 'MIDLDPS', 'MILLMERN', 'MINTARO', 'MOKOSF', 'MOLNGSF1', 'MOORAWF1', 'MORANBAH', 'MBAHNTH', 'MOREESF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:35:46] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:35:47] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['MIDDLSF1', 'MIDLDPS', 'MILLMERN', 'MINTARO', 'MOKOSF', 'MOLNGSF1', 'MOORAWF1', 'MORANBAH', 'MBAHNTH', 'MOREESF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:47] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['MIDDLSF1', 'MIDLDPS', 'MILLMERN', 'MINTARO', 'MOKOSF', 'MOLNGSF1', 'MOORAWF1', 'MORANBAH', 'MBAHNTH', 'MOREESF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:35:47] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 25/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:35:49] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['MWPS', 'MORTLK', 'MRTLSWF', 'MLWF', 'MOUSF', 'MEWF', 'MTGELWF', 'MTMERCER', 'MTMILLAR', 'MP'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:49] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['MWPS', 'MORTLK', 'MRTLSWF', 'MLWF', 'MOUSF', 'MEWF', 'MTGELWF', 'MTMERCER', 'MTMILLAR', 'MP'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:35:50] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:35:50] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['MWPS', 'MORTLK', 'MRTLSWF', 'MLWF', 'MOUSF', 'MEWF', 'MTGELWF', 'MTMERCER', 'MTMILLAR', 'MP'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:50] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['MWPS', 'MORTLK', 'MRTLSWF', 'MLWF', 'MOUSF', 'MEWF', 'MTGELWF', 'MTMERCER', 'MTMILLAR', 'MP'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:35:51] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 26/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:35:52] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['MSTUART', 'MLSP', 'MUCRKSF', 'MUWAWF', 'MURRAY', 'MBPS2', 'MUSSELRO', 'NASF', 'NEVERSF', 'NEWENSF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:52] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['MSTUART', 'MLSP', 'MUCRKSF', 'MUWAWF', 'MURRAY', 'MBPS2', 'MUSSELRO', 'NASF', 'NEVERSF', 'NEWENSF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:35:53] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:35:54] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['MSTUART', 'MLSP', 'MUCRKSF', 'MUWAWF', 'MURRAY', 'MBPS2', 'MUSSELRO', 'NASF', 'NEVERSF', 'NEWENSF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:54] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['MSTUART', 'MLSP', 'MUCRKSF', 'MUWAWF', 'MURRAY', 'MBPS2', 'MUSSELRO', 'NASF', 'NEVERSF', 'NEWENSF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:35:56] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 27/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:35:57] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['NEWPORT', 'NBHWF', 'NUMURKSF', 'NYNGAN', 'OAKEY', 'OAKEY2SF', 'OAKEY1SF', 'OAKLAND', 'OCPS', 'OAKY2'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:35:57] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['NEWPORT', 'NBHWF', 'NUMURKSF', 'NYNGAN', 'OAKEY', 'OAKEY2SF', 'OAKEY1SF', 'OAKLAND', 'OCPS', 'OAKY2'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# ...
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 34/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:36:22] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['TBSF', 'TB2SF', 'TALLAWAR', 'TALWB', 'TVCCPS', 'TARALGA', '0TARONGBESS', 'TARONG', 'TARONGN', 'TARRALEA'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:36:22] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['TBSF', 'TB2SF', 'TALLAWAR', 'TALWB', 'TVCCPS', 'TARALGA', '0TARONGBESS', 'TARONG', 'TARONGN', 'TARRALEA'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:36:23] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:36:24] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['TBSF', 'TB2SF', 'TALLAWAR', 'TALWB', 'TVCCPS', 'TARALGA', '0TARONGBESS', 'TARONG', 'TARONGN', 'TARRALEA'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:36:24] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['TBSF', 'TB2SF', 'TALLAWAR', 'TALWB', 'TVCCPS', 'TARALGA', '0TARONGBESS', 'TARONG', 'TARONGN', 'TARRALEA'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:36:24] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 35/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:36:26] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['TATIARA', 'TATURA', 'TEMPB', 'BLUFF', 'THEDROP', 'TIMWEST', 'TOORAWF', 'TIB', 'TORRIS', 'TOWER'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:36:26] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['TATIARA', 'TATURA', 'TEMPB', 'BLUFF', 'THEDROP', 'TIMWEST', 'TOORAWF', 'TIB', 'TORRIS', 'TOWER'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:36:27] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:36:27] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['TATIARA', 'TATURA', 'TEMPB', 'BLUFF', 'THEDROP', 'TIMWEST', 'TOORAWF', 'TIB', 'TORRIS', 'TOWER'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:36:27] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['TATIARA', 'TATURA', 'TEMPB', 'BLUFF', 'THEDROP', 'TIMWEST', 'TOORAWF', 'TIB', 'TORRIS', 'TOWER'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:36:28] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 36/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:36:30] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['YABULU', 'TGNSS', 'TREVALLN', 'TRIBUTE', 'TULLYSM', 'SNOWY2', 'TUMUT3', 'TUNGATIN', 'ULBESS', 'URANQ'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:36:30] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['YABULU', 'TGNSS', 'TREVALLN', 'TRIBUTE', 'TULLYSM', 'SNOWY2', 'TUMUT3', 'TUNGATIN', 'ULBESS', 'URANQ'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:36:31] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:36:32] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['YABULU', 'TGNSS', 'TREVALLN', 'TRIBUTE', 'TULLYSM', 'SNOWY2', 'TUMUT3', 'TUNGATIN', 'ULBESS', 'URANQ'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:36:32] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['YABULU', 'TGNSS', 'TREVALLN', 'TRIBUTE', 'TULLYSM', 'SNOWY2', 'TUMUT3', 'TUNGATIN', 'ULBESS', 'URANQ'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:36:32] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 37/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:36:34] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['VP', 'VPGS', 'TITREE', 'VICMILL', 'VBB', 'WAGGNSF', 'WLWLSF', 'WALGRV', 'PRDSO_WALPOLE', '0WAMBOWF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:36:34] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['VP', 'VPGS', 'TITREE', 'VICMILL', 'VBB', 'WAGGNSF', 'WLWLSF', 'WALGRV', 'PRDSO_WALPOLE', '0WAMBOWF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:36:35] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:36:36] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['VP', 'VPGS', 'TITREE', 'VICMILL', 'VBB', 'WAGGNSF', 'WLWLSF', 'WALGRV', 'PRDSO_WALPOLE', '0WAMBOWF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:36:36] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['VP', 'VPGS', 'TITREE', 'VICMILL', 'VBB', 'WAGGNSF', 'WLWLSF', 'WALGRV', 'PRDSO_WALPOLE', '0WAMBOWF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:36:36] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 38/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:36:38] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['WANDSF', 'WANDBG', 'WNSF', 'WTAHB', 'WARWSF', 'WATERLWF', 'WPWF', 'WAUBRAWF', 'WELLSF1', 'WELNSF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:36:38] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['WANDSF', 'WANDBG', 'WNSF', 'WTAHB', 'WARWSF', 'WATERLWF', 'WPWF', 'WAUBRAWF', 'WELLSF1', 'WELNSF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:36:38] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:36:39] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['WANDSF', 'WANDBG', 'WNSF', 'WTAHB', 'WARWSF', 'WATERLWF', 'WPWF', 'WAUBRAWF', 'WELLSF1', 'WELNSF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:36:39] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['WANDSF', 'WANDBG', 'WNSF', 'WTAHB', 'WARWSF', 'WATERLWF', 'WPWF', 'WAUBRAWF', 'WELLSF1', 'WELNSF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:36:39] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 39/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:36:41] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['WEMENSF1', 'WESTILLA', 'WKIEWA', 'WSTWYSF', 'WDBESS', 'WDGPH', 'WDBESS2', 'WRSF1', 'WRWF1', 'WHITSF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:36:41] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['WEMENSF1', 'WESTILLA', 'WKIEWA', 'WSTWYSF', 'WDBESS', 'WDGPH', 'WDBESS2', 'WRSF1', 'WRWF1', 'WHITSF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:36:42] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:36:43] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['WEMENSF1', 'WESTILLA', 'WKIEWA', 'WSTWYSF', 'WDBESS', 'WDGPH', 'WDBESS2', 'WRSF1', 'WRWF1', 'WHITSF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:36:43] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['WEMENSF1', 'WESTILLA', 'WKIEWA', 'WSTWYSF', 'WDBESS', 'WDGPH', 'WDBESS2', 'WRSF1', 'WRWF1', 'WHITSF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:36:43] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 40/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:36:45] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['WHIT1', 'WILGAPK', 'WILGAPKB', 'WILLHOV', 'WGWF', 'WINDHILL', 'WINGF1', 'WINGF2', 'WINTSF1', 'WIVENHOE'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:36:45] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['WHIT1', 'WILGAPK', 'WILGAPKB', 'WILLHOV', 'WGWF', 'WINDHILL', 'WINGF1', 'WINGF2', 'WINTSF1', 'WIVENHOE'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:36:45] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:36:46] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['WHIT1', 'WILGAPK', 'WILGAPKB', 'WILLHOV', 'WGWF', 'WINDHILL', 'WINGF1', 'WINGF2', 'WINTSF1', 'WIVENHOE'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:36:46] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['WHIT1', 'WILGAPK', 'WILGAPKB', 'WILLHOV', 'WGWF', 'WINDHILL', 'WINGF1', 'WINGF2', 'WINTSF1', 'WIVENHOE'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:36:47] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 41/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:36:48] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['WOLARSF', 'WOLLERT', 'WONWP', 'WDLNGN', 'WOODLWN', 'WOOLNTH1', 'WOOLGSF', 'WUNUSF', 'WYASF', 'WYANGALA'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:36:48] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['WOLARSF', 'WOLLERT', 'WONWP', 'WDLNGN', 'WOODLWN', 'WOOLNTH1', 'WOOLGSF', 'WUNUSF', 'WYASF', 'WYANGALA'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:36:49] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:36:49] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['WOLARSF', 'WOLLERT', 'WONWP', 'WDLNGN', 'WOODLWN', 'WOOLNTH1', 'WOOLGSF', 'WUNUSF', 'WYASF', 'WYANGALA'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:36:49] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['WOLARSF', 'WOLLERT', 'WONWP', 'WDLNGN', 'WOODLWN', 'WOOLNTH1', 'WOOLGSF', 'WUNUSF', 'WYASF', 'WYANGALA'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:36:50] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Waiting before next batch...
#
# Processing batch 42/42 (10 facilities)
#   Fetching data from 2025-10-01 to 2025-10-08
# [2025-11-06 12:36:51] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['WYANGALB', 'YALLOURN', 'YSWF', 'YAMBUK', 'YARANSF', 'YWNGAHYD', 'YARWUN', 'YATSF1', 'YAWWF', 'YENDONWF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:36:51] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['WYANGALB', 'YALLOURN', 'YSWF', 'YAMBUK', 'YARANSF', 'YWNGAHYD', 'YARWUN', 'YATSF1', 'YAWWF', 'YENDONWF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-01T00:00:00', 'date_end': '2025-10-08T00:00:00'}
# [2025-11-06 12:36:52] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#   Fetching data from 2025-10-08 to 2025-10-08
# [2025-11-06 12:36:53] DEBUG [openelectricity.client.get_facility_data:534] Getting facility data for NEM/['WYANGALB', 'YALLOURN', 'YSWF', 'YAMBUK', 'YARANSF', 'YWNGAHYD', 'YARWUN', 'YATSF1', 'YAWWF', 'YENDONWF'] (metrics: [<DataMetric.POWER: 'power'>, <DataMetric.EMISSIONS: 'emissions'>], interval: 5m)
# [2025-11-06 12:36:53] DEBUG [openelectricity.client.get_facility_data:551] Request parameters: {'facility_code': ['WYANGALB', 'YALLOURN', 'YSWF', 'YAMBUK', 'YARANSF', 'YWNGAHYD', 'YARWUN', 'YATSF1', 'YAWWF', 'YENDONWF'], 'metrics': ['power', 'emissions'], 'interval': '5m', 'date_start': '2025-10-08T00:05:00', 'date_end': '2025-10-08T23:55:00'}
# [2025-11-06 12:36:53] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#     ✓ Fetched 2 facility metric series
#
# [2025-11-06 12:36:54] DEBUG [openelectricity.client.close:600] Closing async client session
#
# Total facility data records fetched: 2240118
# Total market data records fetched: 23020

# %%
# Fetch NEM facility locations

async def fetch_all_facilities():
    """
    Fetch all operational facilities in the NEM network
    
    Returns:
        List of facility data dictionaries
    """
    
    print("\n Connecting to OpenElectricity API...")
    
    async with AsyncOEClient() as client:
        # Fetch all operational facilities in NEM network
        # Correct parameter format: list[str] for network_id
        facilities_response = await client.get_facilities(
            network_id=["NEM"],  # Pass as list
            status_id=[UnitStatusType.OPERATING]  # Pass as list
        )
        
        print(f" Successfully fetched facility data")
        print(f" Total facilities found: {len(facilities_response.data)}")
        
        # Extract and convert facility data
        facilities = []
        
        for facility in facilities_response.data:
            # Handle location data safely
            location_data = None
            if hasattr(facility, 'location') and facility.location:
                location_data = {
                    'lat': facility.location.lat,
                    'lng': facility.location.lng,
                }
            
            # Convert facility object to dictionary
            facility_dict = {
                'code': facility.code if hasattr(facility, 'code') else None,
                'name': facility.name if hasattr(facility, 'name') else 'Unknown',
                'network_id': facility.network_id if hasattr(facility, 'network_id') else None,
                'network_region': facility.network_region if hasattr(facility, 'network_region') else None,
                'description': facility.description if hasattr(facility, 'description') else '',
                'npi_identifier': facility.npi_identifier if hasattr(facility, 'npi_identifier') else None,
                'location': location_data,
                'fueltech': facility.fueltech if hasattr(facility, 'fueltech') else None,
                'status': facility.status if hasattr(facility, 'status') else None,
                'capacity_registered': facility.capacity_registered if hasattr(facility, 'capacity_registered') else 0,
                'unit_ids': facility.unit_ids if hasattr(facility, 'unit_ids') else [],
                'units_number': facility.units_number if hasattr(facility, 'units_number') else 0,
                'created_at': str(facility.created_at) if hasattr(facility, 'created_at') and facility.created_at else None,
                'updated_at': str(facility.updated_at) if hasattr(facility, 'updated_at') and facility.updated_at else None,
            }
            facilities.append(facility_dict)
        
        return facilities

# Execute async function
print("\n Fetching facility data...")
facility_data = await fetch_all_facilities()

print(f"\n Facility data loaded!")
print(f" Total NEM facilities: {len(facility_data)}")

# Display sample facility data structure
if facility_data:
    print("\n Sample facility record structure:")
    sample = facility_data[0]
    print(f"  Keys available: {list(sample.keys())}")
    print(f"\n  Sample facility:")
    print(f"    Code: {sample.get('code', 'N/A')}")
    print(f"    Name: {sample.get('name', 'N/A')}")
    print(f"    Region: {sample.get('network_region', 'N/A')}")
    print(f"    Fuel Type: {sample.get('fueltech', 'N/A')}")
    print(f"    Has Location: {sample['location'] is not None}")
    if sample['location']:
        print(f"    Latitude: {sample['location']['lat']}")
        print(f"    Longitude: {sample['location']['lng']}")

# Show sample facilities with locations
print("\n Sample facilities with locations:")
print("-" * 110)
print(f"{'Facility Name':<50} | {'Code':<12} | {'Region':<5} | {'Lat':>9} | {'Lng':>10}")
print("-" * 110)

count = 0
for facility in facility_data:
    if facility['location'] and facility['location']['lat']:
        print(f"{facility['name'][:48]:<50} | {facility['code']:<12} | "
              f"{facility['network_region'] or 'N/A':<5} | "
              f"{facility['location']['lat']:>9.4f} | {facility['location']['lng']:>10.4f}")
        count += 1
        if count >= 15:
            break

# Quick statistics
total_with_location = sum(1 for f in facility_data if f['location'] and f['location']['lat'])
total_without_location = len(facility_data) - total_with_location

print(f"\n Location Statistics:")
print(f" Facilities with valid locations: {total_with_location} ({total_with_location/len(facility_data)*100:.1f}%)")
print(f" Facilities without locations: {total_without_location} ({total_without_location/len(facility_data)*100:.1f}%)")

# Show distribution by region
from collections import Counter
region_counts = Counter([f['network_region'] for f in facility_data if f['network_region']])
print(f"\n Facilities by Region:")
for region, count in sorted(region_counts.items()):
    print(f"  {region}: {count}")
# Out:
#  Fetching facility data...
#
#  Connecting to OpenElectricity API...
# [2025-11-07 10:56:28] DEBUG [openelectricity.client.__init__:79] Initialized client with base URL: https://api.openelectricity.org.au/v4/
# [2025-11-07 10:56:28] DEBUG [openelectricity.client.__init__:417] Initialized asynchronous client
# [2025-11-07 10:56:28] DEBUG [openelectricity.client._ensure_client:422] Creating new async client session
# [2025-11-07 10:56:29] DEBUG [openelectricity.client.get_facilities:450] Getting facilities
# [2025-11-07 10:56:29] DEBUG [openelectricity.client.get_facilities:461] Request parameters: {'status_id': ['operating'], 'network_id': ['NEM']}
# [2025-11-07 10:56:30] DEBUG [openelectricity.client._handle_response:438] Received successful response: 200
#  Successfully fetched facility data
#  Total facilities found: 420
# [2025-11-07 10:56:30] DEBUG [openelectricity.client.close:600] Closing async client session
#
#  Facility data loaded!
#  Total NEM facilities: 420
#
#  Sample facility record structure:
#   Keys available: ['code', 'name', 'network_id', 'network_region', 'description', 'npi_identifier', 'location', 'fueltech', 'status', 'capacity_registered', 'unit_ids', 'units_number', 'created_at', 'updated_at']
#
#   Sample facility:
#     Code: ADP
#     Name: Adelaide Desalination
#     Region: SA1
#     Fuel Type: None
#     Has Location: True
#     Latitude: -35.096948
#     Longitude: 138.484061
#
#  Sample facilities with locations:
# --------------------------------------------------------------------------------------------------------------
# Facility Name                                      | Code         | Region |       Lat |        Lng
# --------------------------------------------------------------------------------------------------------------
# Adelaide Desalination                              | ADP          | SA1   |  -35.0969 |   138.4841
# Aldoga                                             | ALDGASF      | QLD1  |  -23.8395 |   151.0849
# Angaston                                           | ANGASTON     | SA1   |  -34.5039 |   139.0243
# Appin                                              | APPIN        | NSW1  |  -34.2109 |   150.7927
# Ararat                                             | ARWF         | VIC1  |  -37.2634 |   143.0821
# Avonlie                                            | AVLSF        | NSW1  |  -34.9191 |   146.6095
# Bairnsdale                                         | DEIBDL       | VIC1  |  -37.8422 |   147.5637
# Baking Board                                       | BAKING       | QLD1  |  -26.7212 |   150.5542
# Bald Hills                                         | BHWF         | VIC1  |  -38.7582 |   145.9561
# Ballarat                                           | BALBESS      | VIC1  |  -37.5675 |   143.8527
# Bango                                              | BANGOWF      | NSW1  |  -34.7672 |   148.9215
# Banimboola                                         | BAPS         | VIC1  |  -36.5345 |   147.4598
# Bannerton                                          | BANNSP       | VIC1  |  -34.6726 |   142.7504
# Barcaldine                                         | BARCALDN     | QLD1  |  -23.5522 |   145.3149
# Barcaldine                                         | BARCSF       | QLD1  |  -23.5473 |   145.3190
#
#  Location Statistics:
#  Facilities with valid locations: 420 (100.0%)
#  Facilities without locations: 0 (0.0%)
#
#  Facilities by Region:
#   NSW1: 126
#   QLD1: 100
#   SA1: 62
#   TAS1: 29
#   VIC1: 102
#   WEM: 1

# %%
# Extract location information from facility data 

facility_locations = {}
facilities_without_location = []
invalid_coordinates = []

print(f"\n Processing {len(facility_data)} facility records...")

for record in facility_data:
    try:
        # Extract facility code (required)
        facility_code = record.get('code')
        
        if not facility_code:
            continue
        
        # Extract location object
        location = record.get('location')
        
        if not location or not isinstance(location, dict):
            facilities_without_location.append({
                'code': facility_code,
                'name': record.get('name', 'Unknown'),
                'reason': 'No location object'
            })
            continue
        
        # Extract lat/lng from FacilityLocation object
        lat = location.get('lat')
        lng = location.get('lng')
        
        # Skip if no valid coordinates
        if lat is None or lng is None:
            facilities_without_location.append({
                'code': facility_code,
                'name': record.get('name', 'Unknown'),
                'reason': 'Missing lat/lng in location object'
            })
            continue
        
        # Convert to float and validate
        try:
            lat = float(lat)
            lng = float(lng)
            
            # Basic validation for Australian coordinates
            # Australia: lat ~ -10 to -45, lng ~ 110 to 155
            if not (-50 < lat < 0 and 100 < lng < 160):
                invalid_coordinates.append({
                    'code': facility_code,
                    'name': record.get('name', 'Unknown'),
                    'lat': lat,
                    'lng': lng,
                    'reason': 'Coordinates outside Australia bounds'
                })
                continue
                
        except (ValueError, TypeError) as e:
            facilities_without_location.append({
                'code': facility_code,
                'name': record.get('name', 'Unknown'),
                'reason': f'Invalid coordinate format: {e}'
            })
            continue
        
        # Extract all available facility information (with safe defaults)
        facility_locations[facility_code] = {
            'code': facility_code,
            'name': record.get('name') or 'Unknown',
            'lat': lat,
            'lng': lng,
            'network_id': record.get('network_id') or 'Unknown',
            'network_region': record.get('network_region') or 'Unknown',
            'description': record.get('description') or '',
            'npi_identifier': record.get('npi_identifier') or '',
            'fueltech': record.get('fueltech') or 'Unknown',
            'status': record.get('status') or 'Unknown',  # Ensure not None
            'capacity_registered': float(record.get('capacity_registered') or 0),
            'unit_ids': record.get('unit_ids') or [],
            'units_number': record.get('units_number') or 0,
            'created_at': record.get('created_at') or '',
            'updated_at': record.get('updated_at') or '',
        }
        
    except Exception as e:
        print(f" Error processing facility {record.get('code', 'unknown')}: {e}")
        continue

# Summary statistics
total_processed = len(facility_data)
total_with_locations = len(facility_locations)
total_without_locations = len(facilities_without_location)
total_invalid = len(invalid_coordinates)

print(f"\n" + "=" * 60)
print("EXTRACTION SUMMARY")
print("=" * 60)
print(f" Successfully extracted locations: {total_with_locations}")
print(f" Facilities without location data: {total_without_locations}")
print(f" Invalid coordinates: {total_invalid}")
print(f" Success rate: {(total_with_locations/total_processed*100):.1f}%")

# Show facilities without locations (if any)
if facilities_without_location:
    print(f"\n Facilities without location data (showing first 15):")
    print("-" * 90)
    print(f"{'Code':<15} | {'Facility Name':<50} | {'Reason':<20}")
    print("-" * 90)
    for i, fac in enumerate(facilities_without_location[:15], 1):
        reason = fac.get('reason', 'Unknown')
        print(f"{fac['code']:<15} | {fac['name'][:48]:<50} | {reason:<20}")
    
    if len(facilities_without_location) > 15:
        print(f"... and {len(facilities_without_location) - 15} more")

# Show invalid coordinates (if any)
if invalid_coordinates:
    print(f"\n Facilities with invalid coordinates:")
    print("-" * 100)
    print(f"{'Code':<15} | {'Facility Name':<40} | {'Lat':>10} | {'Lng':>10} | {'Reason':<20}")
    print("-" * 100)
    for fac in invalid_coordinates:
        print(f"{fac['code']:<15} | {fac['name'][:38]:<40} | "
              f"{fac['lat']:>10.4f} | {fac['lng']:>10.4f} | {fac.get('reason', 'N/A'):<20}")

# Display sample of successfully extracted locations
if facility_locations:
    print(f"\n Sample of successfully extracted locations (first 20):")
    print("-" * 120)
    print(f"{'Facility Name':<45} | {'Code':<12} | {'Region':<6} | {'Fuel Type':<15} | {'Lat':>9} | {'Lng':>10}")
    print("-" * 120)
    
    for i, (code, info) in enumerate(list(facility_locations.items())[:20], 1):
        name = (info['name'] or 'Unknown')[:43]
        fueltech = (info['fueltech'] or 'Unknown')[:13]
        region = (info['network_region'] or 'N/A')[:4]
        
        print(f"{name:<45} | {info['code']:<12} | {region:<6} | "
              f"{fueltech:<15} | {info['lat']:>9.4f} | {info['lng']:>10.4f}")
    
    if len(facility_locations) > 20:
        print(f"... and {len(facility_locations) - 20} more facilities")

# Summary message
print(f"\n Data is stored in the 'facility_locations' dictionary")
# Out:
#  Processing 420 facility records...
#
# ============================================================
# EXTRACTION SUMMARY
# ============================================================
#  Successfully extracted locations: 420
#  Facilities without location data: 0
#  Invalid coordinates: 0
#  Success rate: 100.0%
#
#  Sample of successfully extracted locations (first 20):
# ------------------------------------------------------------------------------------------------------------------------
# Facility Name                                 | Code         | Region | Fuel Type       |       Lat |        Lng
# ------------------------------------------------------------------------------------------------------------------------
# Adelaide Desalination                         | ADP          | SA1    | Unknown         |  -35.0969 |   138.4841
# Aldoga                                        | ALDGASF      | QLD1   | Unknown         |  -23.8395 |   151.0849
# Angaston                                      | ANGASTON     | SA1    | Unknown         |  -34.5039 |   139.0243
# Appin                                         | APPIN        | NSW1   | Unknown         |  -34.2109 |   150.7927
# Ararat                                        | ARWF         | VIC1   | Unknown         |  -37.2634 |   143.0821
# Avonlie                                       | AVLSF        | NSW1   | Unknown         |  -34.9191 |   146.6095
# Bairnsdale                                    | DEIBDL       | VIC1   | Unknown         |  -37.8422 |   147.5637
# Baking Board                                  | BAKING       | QLD1   | Unknown         |  -26.7212 |   150.5542
# Bald Hills                                    | BHWF         | VIC1   | Unknown         |  -38.7582 |   145.9561
# Ballarat                                      | BALBESS      | VIC1   | Unknown         |  -37.5675 |   143.8527
# Bango                                         | BANGOWF      | NSW1   | Unknown         |  -34.7672 |   148.9215
# Banimboola                                    | BAPS         | VIC1   | Unknown         |  -36.5345 |   147.4598
# Bannerton                                     | BANNSP       | VIC1   | Unknown         |  -34.6726 |   142.7504
# Barcaldine                                    | BARCALDN     | QLD1   | Unknown         |  -23.5522 |   145.3149
# Barcaldine                                    | BARCSF       | QLD1   | Unknown         |  -23.5473 |   145.3190
# Barker Inlet                                  | BARKIPS      | SA1    | Unknown         |  -34.8040 |   138.5240
# Barron Gorge                                  | BARRON       | QLD1   | Unknown         |  -16.8508 |   145.6470
# Bastyan                                       | BASTYAN      | TAS1   | Unknown         |  -41.7362 |   145.5316
# Bayswater                                     | BAYSW        | NSW1   | Unknown         |  -32.3935 |   150.9540
# Bell Bay Three                                | BBP31        | TAS1   | Unknown         |  -41.1393 |   146.9055
# ... and 400 more facilities
#
#  Data is stored in the 'facility_locations' dictionary

# %%
# Save 'facility_locations' dictionary to pkl file
with open('facility_locations.pkl', 'wb') as f:
    pickle.dump(facility_locations, f)

print(f"✓ Saved {len(facility_locations)} facilities to facility_locations.pkl")
# Out:
# ✓ Saved 420 facilities to facility_locations.pkl

# %% [markdown]
# # 2 Data Integration and Materialization/Caching

# %%
# Convert to DataFrames
df_facility = pd.DataFrame(facility_data)
df_market = pd.DataFrame(market_data)

# %% [markdown]
# ## 2.1 Process Facility Data

# %%
# INSPECT FACILITY DATA STRUCTURE (DETAILED)

# Basic info
print("Facility data basic info:")
print(f"  Shape: {df_facility.shape}")
print(f"  Columns: {list(df_facility.columns)}")
print()

# Data types
print("Data types:")
print(df_facility.dtypes)
print()

# Sample data
print("Sample facility data (first 30 rows):")
print(df_facility.head(30))
print()

# Check unique values for each column
print("="*80)
print("UNIQUE VALUES ANALYSIS")
print("="*80)
print()

print(f"Unique facility_name: {df_facility['facility_name'].nunique()}")
print(f"  Sample facility_names (first 20):")
for i, name in enumerate(sorted(df_facility['facility_name'].unique())[:20], 1):
    print(f"    {i}. {name}")
print()

print(f"Unique metric: {df_facility['metric'].nunique()}")
print(f"  All metrics: {sorted(df_facility['metric'].unique())}")
print()

print(f"Unique timestamps: {df_facility['timestamp'].nunique()}")
print(f"  Timestamp range: {df_facility['timestamp'].min()} to {df_facility['timestamp'].max()}")
print()

# Value statistics by metric
print("="*80)
print("VALUE STATISTICS BY METRIC")
print("="*80)
print()

for metric in sorted(df_facility['metric'].unique()):
    metric_data = df_facility[df_facility['metric'] == metric]
    print(f"\nMetric: {metric}")
    print(f"  Records: {len(metric_data):,}")
    print(f"  Value range: {metric_data['value'].min():.3f} to {metric_data['value'].max():.3f}")
    print(f"  Mean: {metric_data['value'].mean():.3f}")
    
    zero_count = (metric_data['value'] == 0).sum()
    non_zero_count = (metric_data['value'] != 0).sum()
    null_count = metric_data['value'].isna().sum()
    
    print(f"  Zero values: {zero_count:,} ({zero_count/len(metric_data)*100:.2f}%)")
    print(f"  Non-zero values: {non_zero_count:,} ({non_zero_count/len(metric_data)*100:.2f}%)")
    print(f"  Null values: {null_count:,} ({null_count/len(metric_data)*100:.2f}%)")

print()
# Out:
# Facility data basic info:
#   Shape: (2240118, 5)
#   Columns: ['timestamp', 'facility_name', 'metric', 'value', 'unit']
#
# Data types:
# timestamp        datetime64[ns, +10:00]
# facility_name                    object
# metric                           object
# value                           float64
# unit                             object
# dtype: object
#
# Sample facility data (first 30 rows):
#                    timestamp facility_name metric  value unit
# 0  2025-10-01 00:00:00+10:00  power_ADPBA1  power -0.004   MW
# 1  2025-10-01 00:05:00+10:00  power_ADPBA1  power -0.046   MW
# 2  2025-10-01 00:10:00+10:00  power_ADPBA1  power  0.000   MW
# 3  2025-10-01 00:15:00+10:00  power_ADPBA1  power  0.003   MW
# 4  2025-10-01 00:20:00+10:00  power_ADPBA1  power -0.018   MW
# 5  2025-10-01 00:25:00+10:00  power_ADPBA1  power  0.004   MW
# 6  2025-10-01 00:30:00+10:00  power_ADPBA1  power -0.001   MW
# 7  2025-10-01 00:35:00+10:00  power_ADPBA1  power -0.003   MW
# 8  2025-10-01 00:40:00+10:00  power_ADPBA1  power  0.076   MW
# 9  2025-10-01 00:45:00+10:00  power_ADPBA1  power -0.001   MW
# 10 2025-10-01 00:50:00+10:00  power_ADPBA1  power  0.058   MW
# 11 2025-10-01 00:55:00+10:00  power_ADPBA1  power -0.017   MW
# 12 2025-10-01 01:00:00+10:00  power_ADPBA1  power  0.005   MW
# 13 2025-10-01 01:05:00+10:00  power_ADPBA1  power  0.027   MW
# 14 2025-10-01 01:10:00+10:00  power_ADPBA1  power  0.003   MW
# 15 2025-10-01 01:15:00+10:00  power_ADPBA1  power  0.000   MW
# 16 2025-10-01 01:20:00+10:00  power_ADPBA1  power  0.000   MW
# 17 2025-10-01 01:25:00+10:00  power_ADPBA1  power -0.010   MW
# 18 2025-10-01 01:30:00+10:00  power_ADPBA1  power  0.006   MW
# 19 2025-10-01 01:35:00+10:00  power_ADPBA1  power -0.029   MW
# 20 2025-10-01 01:40:00+10:00  power_ADPBA1  power  0.070   MW
# 21 2025-10-01 01:45:00+10:00  power_ADPBA1  power -0.081   MW
# 22 2025-10-01 01:50:00+10:00  power_ADPBA1  power -0.004   MW
# 23 2025-10-01 01:55:00+10:00  power_ADPBA1  power -0.019   MW
# 24 2025-10-01 02:00:00+10:00  power_ADPBA1  power -0.016   MW
# 25 2025-10-01 02:05:00+10:00  power_ADPBA1  power  0.006   MW
# 26 2025-10-01 02:10:00+10:00  power_ADPBA1  power -0.003   MW
# 27 2025-10-01 02:15:00+10:00  power_ADPBA1  power  0.009   MW
# 28 2025-10-01 02:20:00+10:00  power_ADPBA1  power -0.006   MW
# 29 2025-10-01 02:25:00+10:00  power_ADPBA1  power -0.002   MW
#
# ================================================================================
# UNIQUE VALUES ANALYSIS
# ================================================================================
#
# Unique facility_name: 1066
#   Sample facility_names (first 20):
#     1. emissions_ADPBA1
#     2. emissions_ADPBA1G
#     3. emissions_ADPBA1L
#     4. emissions_ADPPV1
#     5. emissions_AGLHAL
#     6. emissions_AGLSOM
#     7. emissions_ALDGASF1
#     8. emissions_ANGAST1
#     9. emissions_ARWF1
#     10. emissions_AVLSF1
#     11. emissions_BALB1
#     12. emissions_BALBG1
#     13. emissions_BALBL1
#     14. emissions_BALDHWF1
#     15. emissions_BANGOWF1
#     16. emissions_BANGOWF2
#     17. emissions_BANN1
#     18. emissions_BARCALDN
#     19. emissions_BARCSF1
#     20. emissions_BARKIPS1
#
# Unique metric: 2
#   All metrics: ['emissions', 'power']
#
# Unique timestamps: 2302
#   Timestamp range: 2025-10-01 00:00:00+10:00 to 2025-10-08 23:50:00+10:00
#
# ================================================================================
# VALUE STATISTICS BY METRIC
# ================================================================================
#
#
# Metric: emissions
#   Records: 1,120,059
#   Value range: 0.000 to 54.659
#   Mean: 1.799
#   Zero values: 1,000,732 (89.35%)
#   Non-zero values: 119,327 (10.65%)
#   Null values: 0 (0.00%)
#
# Metric: power
#   Records: 1,120,059
#   Value range: -776.252 to 1791.730
#   Mean: 42.124
#   Zero values: 463,660 (41.40%)
#   Non-zero values: 656,399 (58.60%)
#   Null values: 0 (0.00%)

# %%
# Remove 'power_' prefix
df_facility['facility_code'] = df_facility['facility_name'].str.replace(
    r'^power_', '', regex=True
)

print("After removing 'power_' prefix:")
print(f"  Unique facility codes: {df_facility['facility_code'].nunique()}")
print(f"  Sample: {df_facility['facility_code'].unique()[:10]}")
print()
# Out:
# After removing 'power_' prefix:
#   Unique facility codes: 1066
#   Sample: ['ADPBA1' 'ADPBA1G' 'ADPPV1' 'ALDGASF1' 'ANGAST1' 'ARWF1' 'AVLSF1' 'BALB1'
#  'BALBG1' 'BALDHWF1']

# %%
# Also remove 'emissions_' prefix 
df_facility['facility_code'] = df_facility['facility_code'].str.replace(
    r'^emissions_', '', regex=True
)

print("After removing 'emissions_' prefix:")
print(f"  Unique facility codes: {df_facility['facility_code'].nunique()}")
print(f"  Sample: {df_facility['facility_code'].unique()[:10]}")
print()
# Out:
# After removing 'emissions_' prefix:
#   Unique facility codes: 533
#   Sample: ['ADPBA1' 'ADPBA1G' 'ADPPV1' 'ALDGASF1' 'ANGAST1' 'ARWF1' 'AVLSF1' 'BALB1'
#  'BALBG1' 'BALDHWF1']

# %%
# CONVERT METRICS TO COLUMNS

# Use pivot_table to convert metric rows to columns
df_facility_pivot = df_facility.pivot_table(
    index=['timestamp', 'facility_code'],
    columns='metric',
    values='value',
    aggfunc='first'
).reset_index()

# Remove the 'metric' name from columns
df_facility_pivot.columns.name = None

print(f"✓ Pivoted facility data shape: {df_facility_pivot.shape}")
print(f"✓ Columns after pivot: {list(df_facility_pivot.columns)}")
print()

# Display sample pivoted data
print("Sample pivoted facility data (first 10 rows):")
print(df_facility_pivot.head(10))
print()
# Out:
# ✓ Pivoted facility data shape: (1120059, 4)
# ✓ Columns after pivot: ['timestamp', 'facility_code', 'emissions', 'power']
#
# Sample pivoted facility data (first 10 rows):
#                   timestamp facility_code  emissions   power
# 0 2025-10-01 00:00:00+10:00        ADPBA1        0.0  -0.004
# 1 2025-10-01 00:00:00+10:00       ADPBA1L        0.0   0.004
# 2 2025-10-01 00:00:00+10:00        ADPPV1        0.0   0.000
# 3 2025-10-01 00:00:00+10:00        AGLHAL        0.0   0.000
# 4 2025-10-01 00:00:00+10:00        AGLSOM        0.0   0.000
# 5 2025-10-01 00:00:00+10:00      ALDGASF1        0.0   0.000
# 6 2025-10-01 00:00:00+10:00       ANGAST1        0.0   0.000
# 7 2025-10-01 00:00:00+10:00         ARWF1        0.0  35.400
# 8 2025-10-01 00:00:00+10:00        AVLSF1        0.0   0.000
# 9 2025-10-01 00:00:00+10:00         BALB1        0.0   0.000

# %%
# CHECK FOR NULL VALUES AFTER PIVOT4

null_counts = df_facility_pivot.isnull().sum()

for col, count in null_counts.items():
    if count > 0:
        print("Null value counts by column:")
        pct = (count / len(df_facility_pivot)) * 100
        print(f"  {col}: {count:,} ({pct:.2f}%)")

if null_counts.sum() == 0:
    print(" No null values found")
print()
# Out:
#  No null values found

# %%
# ADD TIME COMPONENTS TO FACILITY DATA

# Ensure timestamp is datetime
df_facility_pivot['timestamp'] = pd.to_datetime(df_facility_pivot['timestamp'])

# Add date and hour columns
df_facility_pivot['date'] = df_facility_pivot['timestamp'].dt.date
df_facility_pivot['hour'] = df_facility_pivot['timestamp'].dt.hour

print("Added 'date' and 'hour' columns")
print(f" Timestamp range: {df_facility_pivot['timestamp'].min()} to {df_facility_pivot['timestamp'].max()}")
print(f" Date range: {df_facility_pivot['date'].min()} to {df_facility_pivot['date'].max()}")
print(f" Hour range: {df_facility_pivot['hour'].min()} to {df_facility_pivot['hour'].max()}")
print()

# Display updated columns
print(f"Updated columns: {list(df_facility_pivot.columns)}")
print()
# Out:
# Added 'date' and 'hour' columns
#  Timestamp range: 2025-10-01 00:00:00+10:00 to 2025-10-08 23:50:00+10:00
#  Date range: 2025-10-01 to 2025-10-08
#  Hour range: 0 to 23
#
# Updated columns: ['timestamp', 'facility_code', 'emissions', 'power', 'date', 'hour']

# %%
# REORDER COLUMNS FOR FACILITY DATA

# Check which metric columns exist
metric_cols = []
if 'emissions' in df_facility_pivot.columns:
    metric_cols.append('emissions')
if 'power' in df_facility_pivot.columns:
    metric_cols.append('power')


# Define desired column order
base_cols = ['timestamp', 'date', 'hour', 'facility_code']
final_cols = base_cols + metric_cols

# Reorder columns
df_facility_pivot = df_facility_pivot[final_cols]

# %%
# Final facility data shape
print(f"Shape: {df_facility_pivot.shape}")
print(f"Columns: {list(df_facility_pivot.columns)}")

# Display final sample
print("Final facility data sample (first 10 rows):")
print(df_facility_pivot.head(10))
print()
# Out:
# Shape: (1120059, 6)
# Columns: ['timestamp', 'date', 'hour', 'facility_code', 'emissions', 'power']
# Final facility data sample (first 10 rows):
#                   timestamp        date  hour facility_code  emissions   power
# 0 2025-10-01 00:00:00+10:00  2025-10-01     0        ADPBA1        0.0  -0.004
# 1 2025-10-01 00:00:00+10:00  2025-10-01     0       ADPBA1L        0.0   0.004
# 2 2025-10-01 00:00:00+10:00  2025-10-01     0        ADPPV1        0.0   0.000
# 3 2025-10-01 00:00:00+10:00  2025-10-01     0        AGLHAL        0.0   0.000
# 4 2025-10-01 00:00:00+10:00  2025-10-01     0        AGLSOM        0.0   0.000
# 5 2025-10-01 00:00:00+10:00  2025-10-01     0      ALDGASF1        0.0   0.000
# 6 2025-10-01 00:00:00+10:00  2025-10-01     0       ANGAST1        0.0   0.000
# 7 2025-10-01 00:00:00+10:00  2025-10-01     0         ARWF1        0.0  35.400
# 8 2025-10-01 00:00:00+10:00  2025-10-01     0        AVLSF1        0.0   0.000
# 9 2025-10-01 00:00:00+10:00  2025-10-01     0         BALB1        0.0   0.000

# %% [markdown]
# ## 2.2 Process Market Data

# %%
# INSPECT MARKET DATA STRUCTURE

# Basic info
print("Market data basic info:")
print(f"  Shape: {df_market.shape}")
print(f"  Columns: {list(df_market.columns)}")
print()

# Data types
print("Data types:")
print(df_market.dtypes)
print()

# Sample data
print("Sample market data (first 20 rows):")
print(df_market.head(20))
print()

# Check unique values
print("Unique values:")
print(f"  Unique regions: {df_market['region'].nunique()}")
print(f"    Regions: {sorted(df_market['region'].unique())}")
print()

if 'market_name' in df_market.columns:
    print(f"  Unique market_name: {df_market['market_name'].nunique()}")
    print(f"    Market names: {sorted(df_market['market_name'].unique())}")
    print()

# Check timestamp range
print(f"  Timestamp range: {df_market['timestamp'].min()} to {df_market['timestamp'].max()}")
print(f"  Unique timestamps: {df_market['timestamp'].nunique()}")
print()

# Value statistics
print("Value statistics:")
print(df_market['value'].describe())
print()

# Check for zero/non-zero values
zero_values = (df_market['value'] == 0).sum()
non_zero_values = (df_market['value'] != 0).sum()
null_values = df_market['value'].isna().sum()

print(f"  Zero values: {zero_values:,} ({zero_values/len(df_market)*100:.2f}%)")
print(f"  Non-zero values: {non_zero_values:,} ({non_zero_values/len(df_market)*100:.2f}%)")
print(f"  Null values: {null_values:,} ({null_values/len(df_market)*100:.2f}%)")
print()

# Sample non-zero values
print("Sample non-zero market data:")
print(df_market[df_market['value'] != 0].head(10))
print()
# Out:
# Market data basic info:
#   Shape: (23020, 5)
#   Columns: ['timestamp', 'region', 'metric', 'value', 'unit']
#
# Data types:
# timestamp    datetime64[ns, +10:00]
# region                       object
# metric                       object
# value                       float64
# unit                         object
# dtype: object
#
# Sample market data (first 20 rows):
#                    timestamp region metric  value   unit
# 0  2025-10-01 00:00:00+10:00   NSW1  price  56.98  $/MWh
# 1  2025-10-01 00:05:00+10:00   NSW1  price  80.01  $/MWh
# 2  2025-10-01 00:10:00+10:00   NSW1  price  58.40  $/MWh
# 3  2025-10-01 00:15:00+10:00   NSW1  price  80.01  $/MWh
# 4  2025-10-01 00:20:00+10:00   NSW1  price  65.00  $/MWh
# 5  2025-10-01 00:25:00+10:00   NSW1  price  63.83  $/MWh
# 6  2025-10-01 00:30:00+10:00   NSW1  price  61.05  $/MWh
# 7  2025-10-01 00:35:00+10:00   NSW1  price  57.13  $/MWh
# 8  2025-10-01 00:40:00+10:00   NSW1  price  61.05  $/MWh
# 9  2025-10-01 00:45:00+10:00   NSW1  price  57.01  $/MWh
# 10 2025-10-01 00:50:00+10:00   NSW1  price  65.00  $/MWh
# 11 2025-10-01 00:55:00+10:00   NSW1  price  59.48  $/MWh
# 12 2025-10-01 01:00:00+10:00   NSW1  price  56.98  $/MWh
# 13 2025-10-01 01:05:00+10:00   NSW1  price  62.43  $/MWh
# 14 2025-10-01 01:10:00+10:00   NSW1  price  80.01  $/MWh
# 15 2025-10-01 01:15:00+10:00   NSW1  price  69.31  $/MWh
# 16 2025-10-01 01:20:00+10:00   NSW1  price  57.01  $/MWh
# 17 2025-10-01 01:25:00+10:00   NSW1  price  57.01  $/MWh
# 18 2025-10-01 01:30:00+10:00   NSW1  price  60.79  $/MWh
# 19 2025-10-01 01:35:00+10:00   NSW1  price  68.15  $/MWh
#
# Unique values:
#   Unique regions: 5
#     Regions: ['NSW1', 'QLD1', 'SA1', 'TAS1', 'VIC1']
#
#   Timestamp range: 2025-10-01 00:00:00+10:00 to 2025-10-08 23:50:00+10:00
#   Unique timestamps: 2302
#
# Value statistics:
# count    22795.000000
# mean      1900.529369
# std       2539.929113
# min       -235.010000
# 25%          5.020000
# 50%        305.000000
# 75%       4099.605000
# max       9219.090000
# Name: value, dtype: float64
#
#   Zero values: 139 (0.60%)
#   Non-zero values: 22,881 (99.40%)
#   Null values: 225 (0.98%)
#
# Sample non-zero market data:
#                   timestamp region metric  value   unit
# 0 2025-10-01 00:00:00+10:00   NSW1  price  56.98  $/MWh
# 1 2025-10-01 00:05:00+10:00   NSW1  price  80.01  $/MWh
# 2 2025-10-01 00:10:00+10:00   NSW1  price  58.40  $/MWh
# 3 2025-10-01 00:15:00+10:00   NSW1  price  80.01  $/MWh
# 4 2025-10-01 00:20:00+10:00   NSW1  price  65.00  $/MWh
# 5 2025-10-01 00:25:00+10:00   NSW1  price  63.83  $/MWh
# 6 2025-10-01 00:30:00+10:00   NSW1  price  61.05  $/MWh
# 7 2025-10-01 00:35:00+10:00   NSW1  price  57.13  $/MWh
# 8 2025-10-01 00:40:00+10:00   NSW1  price  61.05  $/MWh
# 9 2025-10-01 00:45:00+10:00   NSW1  price  57.01  $/MWh

# %%
# Pivot market data
df_market_pivot = df_market.pivot_table(
    index=['timestamp', 'region'],
    columns='metric',
    values='value',
    aggfunc='first'
).reset_index()

print(f"Pivoted market data shape: {df_market_pivot.shape}")
print(f"Columns: {list(df_market_pivot.columns)}")
print()
# Out:
# Pivoted market data shape: (11490, 4)
# Columns: ['timestamp', 'region', 'demand', 'price']

# %%
# Add hour and date columns
df_facility_pivot['timestamp'] = pd.to_datetime(df_facility_pivot['timestamp'])
df_facility_pivot['hour'] = df_facility_pivot['timestamp'].dt.hour
df_facility_pivot['date'] = df_facility_pivot['timestamp'].dt.date

df_market_pivot['timestamp'] = pd.to_datetime(df_market_pivot['timestamp'])
df_market_pivot['hour'] = df_market_pivot['timestamp'].dt.hour
df_market_pivot['date'] = df_market_pivot['timestamp'].dt.date

# %%
# Final column ordering
# Reorder facility columns for better readability
facility_cols = ['timestamp', 'date', 'hour', 'facility_name', 'facility_code', 
                 'region', 'emissions', 'power']
# Only select columns that exist
facility_cols_exist = [col for col in facility_cols if col in df_facility_pivot.columns]
# Add any remaining columns
remaining_cols = [col for col in df_facility_pivot.columns if col not in facility_cols_exist]
df_facility_pivot = df_facility_pivot[facility_cols_exist + remaining_cols]

# Reorder market columns
market_cols = ['timestamp', 'date', 'hour', 'region', 'demand', 'price']
market_cols_exist = [col for col in market_cols if col in df_market_pivot.columns]
remaining_market_cols = [col for col in df_market_pivot.columns if col not in market_cols_exist]
df_market_pivot = df_market_pivot[market_cols_exist + remaining_market_cols]

# %%
# Final Market data shape
print(f"Shape: {df_market_pivot.shape}")
print(f"Columns: {list(df_market_pivot.columns)}")

# Display final sample
print("Final market data sample (first 10 rows):")
print(df_market_pivot.head(10))
print()
# Out:
# Shape: (11490, 6)
# Columns: ['timestamp', 'date', 'hour', 'region', 'demand', 'price']
# Final market data sample (first 10 rows):
# metric                 timestamp        date  hour region   demand  price
# 0      2025-10-01 00:00:00+10:00  2025-10-01     0   NSW1  7105.57  56.98
# 1      2025-10-01 00:00:00+10:00  2025-10-01     0   QLD1  5989.24  54.82
# 2      2025-10-01 00:00:00+10:00  2025-10-01     0    SA1  1564.92   8.11
# 3      2025-10-01 00:00:00+10:00  2025-10-01     0   TAS1   898.71   0.12
# 4      2025-10-01 00:00:00+10:00  2025-10-01     0   VIC1  4893.49   8.95
# 5      2025-10-01 00:05:00+10:00  2025-10-01     0   NSW1  7170.68  80.01
# 6      2025-10-01 00:05:00+10:00  2025-10-01     0   QLD1  5920.40  67.30
# 7      2025-10-01 00:05:00+10:00  2025-10-01     0    SA1  1565.38   0.01
# 8      2025-10-01 00:05:00+10:00  2025-10-01     0   TAS1   897.18   0.20
# 9      2025-10-01 00:05:00+10:00  2025-10-01     0   VIC1  4889.73   0.01

# %% [markdown]
# ## 2.3 Save Facility and Market data to CSV files

# %%
# Create output directory
output_dir = 'nem_data_output'
os.makedirs(output_dir, exist_ok=True)

# Save facility data
facility_file = os.path.join(output_dir, 'nem_facility_data.csv')
df_facility_pivot.to_csv(facility_file, index=False)
file_size_mb = os.path.getsize(facility_file) / (1024 * 1024)
print(f"✓ Saved: {facility_file}")
print(f"  Rows: {len(df_facility_pivot):,}")
print(f"  Columns: {len(df_facility_pivot.columns)}")
print(f"  Size: {file_size_mb:.2f} MB")
print()

# Save market data
market_file = os.path.join(output_dir, 'nem_market_data.csv')
df_market_pivot.to_csv(market_file, index=False)
file_size_mb = os.path.getsize(market_file) / (1024 * 1024)
print(f"✓ Saved: {market_file}")
print(f"  Rows: {len(df_market_pivot):,}")
print(f"  Columns: {len(df_market_pivot.columns)}")
print(f"  Size: {file_size_mb:.2f} MB")
print()
# Out:
# ✓ Saved: nem_data_output\nem_facility_data.csv
#   Rows: 1,120,059
#   Columns: 6
#   Size: 62.18 MB
#
# ✓ Saved: nem_data_output\nem_market_data.csv
#   Rows: 11,490
#   Columns: 6
#   Size: 0.65 MB

# %% [markdown]
# # 3. Data Publishing via MQTT

# %%
# MQTT Configuration

# UNIQUE TOPIC
MQTT_TOPIC = "szha0285/ass2"

# Broker Selection
USE_TEST_BROKER = False  # Set to False for campus broker, set to True for test broker

if USE_TEST_BROKER:
    BROKER_HOST = "test.mosquitto.org"
    BROKER_PORT = 1883
else:
    BROKER_HOST = "172.17.34.107"
    BROKER_PORT = 1883

print(f"MQTT Broker: {BROKER_HOST}:{BROKER_PORT}")
print(f"MQTT Topic: {MQTT_TOPIC}")
# Out:
# MQTT Broker: 172.17.34.107:1883
# MQTT Topic: szha0285/ass2

# %%
# MQTT Setup

# Define what happens upon connection to the server
def on_connect(client, userdata, connect_flags, reason_code, properties):
    if reason_code == 0:
        print(f"✓ Connected successfully (result code: {reason_code})")
        client.subscribe(MQTT_TOPIC)
        print(f"✓ Subscribed to topic: {MQTT_TOPIC}")
    else:
        print(f"✗ Connection failed with result code: {reason_code}")

# Define what happens upon receiving a message from the server
def on_message(client, userdata, msg):
    print(f"Received message on topic {msg.topic}: {msg.payload.decode()}")

# Define what happens on disconnect
def on_disconnect(client, userdata, disconnect_flags, reason_code, properties):
    if reason_code != 0:
        print(f"✗ Unexpected disconnection (code: {reason_code})")

# Create MQTT client
client = mqtt.Client(mqtt.CallbackAPIVersion.VERSION2)
client.on_connect = on_connect
client.on_message = on_message
client.on_disconnect = on_disconnect

# Connect to the MQTT server with timeout handling
print("\nConnecting to MQTT broker...")
print(f"Attempting connection to {BROKER_HOST}:{BROKER_PORT}...")
try:
    # Set a socket timeout to detect connection issues faster
    client.connect(BROKER_HOST, BROKER_PORT, keepalive=60)
    print("✓ Connection initiated")
    
    # Start the network loop in background
    client.loop_start()
    
    # Wait for connection to complete
    print("Waiting for connection to establish...")
    time.sleep(3)
    
    print("✓ MQTT client ready")
    
except Exception as e:
    print(f"✗ Failed to connect: {e}")
    print("\n TROUBLESHOOTING:")
    print("  1. Check if you're connected to the university network/VPN")
    print("  2. Verify the broker IP address is correct")
    print("  3. If using a public test broker (test.mosquitto.org):")
    raise
# Out:
# Connecting to MQTT broker...
# Attempting connection to 172.17.34.107:1883...
# ✓ Connection initiated
# Waiting for connection to establish...
# ✓ Connected successfully (result code: Success)
# ✓ Subscribed to topic: szha0285/ass2
# ✓ MQTT client ready
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "ADPBA1", "power_mw": -0.004, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "QBYNB1", "power_mw": -0.1765, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "PUMP2", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "PUMP1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "PTSTAN1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "PPCCGT", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "PORTWF", "power_mw": 59.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "POR03", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "POR01", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "POAT220", "power_mw": 3.31, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "POAT110", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "PIONEER", "power_mw": 43.2, "emissions_tco2e": 0.0724, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "PIBESSG1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "QBYNBL1", "power_mw": 0.1765, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "PIBESS1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "PAREPW1", "power_mw": 48.43, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "PAREPS1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "PALOONA", "power_mw": 29.41, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "OSB-AG", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "OAKLAND1", "power_mw": 34.4, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "OAKEY2SF", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "OAKEY2", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "OAKEY1SF", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "OAKEY1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "NYNGAN1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "NUMURSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "NPS", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "PARSF1", "power_mw": 0.0015, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "NEWENSF2", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "QPS1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "QPS3", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SHOAL1", "power_mw": 43.47, "emissions_tco2e": 2.1815, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SHGEN", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SEBSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SAPHWF1", "power_mw": 233.2479, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SALTCRK1", "power_mw": 15.35, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "RYEPARK1", "power_mw": 202.6951, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "RYANCWF1", "power_mw": 75.16, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "RUGBYR1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "RUBICON", "power_mw": 0.585, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "RRSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "RPCG", "power_mw": 13.8, "emissions_tco2e": 0.0509, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "ROYALLA1", "power_mw": 0.001, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "QPS2", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "ROWALLAN", "power_mw": -0.0049, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "ROMA_7", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "RIVNBL2", "power_mw": 0.1151, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "RIVNB2", "power_mw": -0.1151, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "RESS1L", "power_mw": 0.6804, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "RESS1", "power_mw": -0.6804, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "REPULSE", "power_mw": 32.8856, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "REECE2", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "REECE1", "power_mw": 118.8699, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "RANGEB1G1", "power_mw": 0.05, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "RANGEB1", "power_mw": 0.05, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "QPS5", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "QPS4", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "ROMA_8", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "NEWENSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "NEVERSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "NBHWF1", "power_mw": 106.2, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MOKOSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MLWF1", "power_mw": 11.55, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MLSP1", "power_mw": 0.013, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MINTARO", "power_mw": 0.0854, "emissions_tco2e": 0.0061, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MIDDLSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MEWF1", "power_mw": 49.5002, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "METZSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MERCER01", "power_mw": 78.1, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MEADOWBK", "power_mw": 43.4416, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MCKAY1", "power_mw": 0.02, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MCINTYR1", "power_mw": 139.076, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MBPS2PV1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MOLNGSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MBAHNTH", "power_mw": 20.2, "emissions_tco2e": 1.0736, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MAPS3PV1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MAPS2PV1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MANSLR1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MANNUMBL1", "power_mw": 0.18, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MANNUMB1", "power_mw": -0.18, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MANNSF2", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MACKNTSH", "power_mw": 51.81, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MACARTH1", "power_mw": 126.2, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "LYA4", "power_mw": 418.0, "emissions_tco2e": 40.438, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "LYA3", "power_mw": 419.0, "emissions_tco2e": 40.5348, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "LYA2", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "LYA1", "power_mw": 415.0, "emissions_tco2e": 40.1478, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MARYRSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MOORAWF1", "power_mw": 248.89, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MOREESF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MORTLK11", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MWPS4PV1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MWPS3PV1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MWPS2PV1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MWPS1PV1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MUWAWF2", "power_mw": 177.3, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MUWAWF1", "power_mw": 202.65, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MUSSELR1", "power_mw": 46.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MURRAY", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MUCRKSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MTMILLAR", "power_mw": 34.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MTGELWF1", "power_mw": 59.5233, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MSTUART3", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MSTUART2", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MSTUART1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MRTLSWF1", "power_mw": 89.57, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MREHAG3", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MREHAG2", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MREHAG1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MREHA3", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MREHA2", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MREHA1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MPP_2", "power_mw": 431.0752, "emissions_tco2e": 30.0782, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MPP_1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MP2", "power_mw": 447.0405, "emissions_tco2e": 32.3769, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MP1", "power_mw": 448.8472, "emissions_tco2e": 32.5077, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MOUSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "MORTLK12", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SITHE01", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "LRSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SMCSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SMTHBES1L1", "power_mw": 0.0458, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WHITSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WGWF1", "power_mw": 106.9, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WEMENSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WELNSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WELLSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WDGPH1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WDBESSL2", "power_mw": 0.2541, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WDBESSG1", "power_mw": 0.2433, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WDBESS2", "power_mw": -0.2541, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WDBESS1", "power_mw": 0.2433, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WAUBRAWF", "power_mw": 53.4722, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WATERLWF", "power_mw": 103.5, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WINTSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WARWSF2", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WANDSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WANDBG1", "power_mw": 2.2464, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WANDB1", "power_mw": 2.2464, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WAMBOWF1", "power_mw": 65.23, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WALGRVL1", "power_mw": 0.2094, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WALGRV1", "power_mw": -0.2094, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WAGGNSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "W/HOE#2", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "W/HOE#1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "VPGS6", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "VPGS5", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "VPGS4", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WARWSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "VPGS3", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WKIEWA1", "power_mw": 16.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WLWLSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "YWPS4", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "YWPS3", "power_mw": 359.1563, "emissions_tco2e": 38.9056, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "YWPS2", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "YWPS1", "power_mw": 250.75, "emissions_tco2e": 27.1625, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "YSWF1", "power_mw": 20.2, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "YENDWF1", "power_mw": 94.95, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "YATSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "YARWUN_1", "power_mw": 85.01, "emissions_tco2e": 4.344, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "YARANSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "YAMBUKWF", "power_mw": 4.9, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "YABULU2", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "YABULU", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WKIEWA2", "power_mw": 16.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WYASF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WTAHB1G1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WTAHB1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WSTWYSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WRWF1", "power_mw": 36.9018, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WRSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WPWF", "power_mw": 44.05, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WOOLNTH1", "power_mw": 25.97, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WOOLGSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WOODLWN1", "power_mw": 13.9968, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WOLARSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WNSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WLWLSF2", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "WUNUSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "VPGS2", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "VPGS1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "VP6", "power_mw": 597.0642, "emissions_tco2e": 49.1433, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TARONG#2", "power_mw": 220.0, "emissions_tco2e": 16.2011, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TARONG#1", "power_mw": 0.6, "emissions_tco2e": 0.0442, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TARBESSG1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TARBESS1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TARALGA1", "power_mw": 48.6976, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TALWB1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TALWA1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SWAN_E", "power_mw": -0.58, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SUNTPSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SUNRSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "STWF1", "power_mw": 136.271, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "STOCKYD1", "power_mw": 337.78, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TARONG#3", "power_mw": 219.2, "emissions_tco2e": 16.1423, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "STARHLWF", "power_mw": 6.6981, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "STAN-3", "power_mw": 244.4995, "emissions_tco2e": 17.4634, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "STAN-2", "power_mw": 158.5049, "emissions_tco2e": 11.3212, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "STAN-1", "power_mw": 245.2302, "emissions_tco2e": 17.5155, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SRSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SNUG1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SNOWYP", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SNOWTWN1", "power_mw": 92.5856, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SNOWSTH1", "power_mw": 114.5, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SNOWNTH1", "power_mw": 126.7, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SNBG01", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SNB01", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SNAPPER1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "STAN-4", "power_mw": 244.6021, "emissions_tco2e": 17.4707, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TARONG#4", "power_mw": 219.3, "emissions_tco2e": 16.1496, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TARRALEA", "power_mw": 59.7, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TB2B1", "power_mw": -0.3472, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "VP5", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "VBBL1", "power_mw": 0.3, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "VBB1", "power_mw": -0.3, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "URANQ14", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "URANQ13", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "URANQ12", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "URANQ11", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "UPPTUMUT", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "ULPBESSL1", "power_mw": 0.6, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "ULPBESS1", "power_mw": -0.6, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TVPP104", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TVCC201", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TUNGATIN", "power_mw": 80.25, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TUMUT3", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TULLYSM1", "power_mw": 9.9, "emissions_tco2e": 0.0149, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TRIBUTE", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TREVALLN", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TORRB4", "power_mw": 40.0, "emissions_tco2e": 1.9193, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TORRB3", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TORRB2", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TORRB1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TNPS1", "power_mw": 278.5, "emissions_tco2e": 19.5832, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TIBL1", "power_mw": 4.55, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TIB1", "power_mw": -4.55, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TBSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TB2SF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "TB2BG1", "power_mw": 0.3472, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SMTHBES1", "power_mw": -0.0458, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "LOYYB2", "power_mw": 453.75, "emissions_tco2e": 42.437, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "SHPUMP", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "LONSDALE", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CLRKCWF1", "power_mw": 296.108, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CLOVER", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CLERMSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CLEMGPWF", "power_mw": 50.6406, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CLARESF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CHYTWF1", "power_mw": 11.31, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CHILDSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CHBESSL1", "power_mw": 0.039, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CHBESS1", "power_mw": -0.039, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CHALLHWF", "power_mw": 26.7, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CG4", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CG3", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CLRKCWF2", "power_mw": 42.7622, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CG2", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CETHANA", "power_mw": 47.4704, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CBWWBA1L", "power_mw": 0.002, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CBWWBA1", "power_mw": -0.002, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CATHROCK", "power_mw": 40.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CAPTL_WF", "power_mw": 114.2947, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CAPBES1L", "power_mw": 1.25, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CAPBES1", "power_mw": -1.25, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CALL_B_2", "power_mw": 278.4, "emissions_tco2e": 22.1699, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CALL_B_1", "power_mw": 279.2, "emissions_tco2e": 22.2337, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "BWTR1", "power_mw": -25.3219, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "BW04", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "BW03", "power_mw": 581.9302, "emissions_tco2e": 43.252, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CG1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CLUNY", "power_mw": 18.0641, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "CNUNDAWF", "power_mw": 26.9314, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "COHUNSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "DPNTBL1", "power_mw": 0.0493, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "DPNTB1", "power_mw": -0.0493, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "DIAPURWF1", "power_mw": 7.3, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "DEVILS_G", "power_mw": 46.1123, "emissions_tco2e": 0.0, "hour": 0}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T00:00:00+10:00", "facility_code": "DDSF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 0}
# ...
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "STWF1", "power_mw": 85.3376, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "STOCKYD1", "power_mw": 342.29, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "STARHLWF", "power_mw": 6.6981, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "STAN-4", "power_mw": 234.6683, "emissions_tco2e": 16.9525, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "STAN-3", "power_mw": 234.617, "emissions_tco2e": 16.9607, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "STAN-1", "power_mw": 233.1045, "emissions_tco2e": 16.8674, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "SRSF1", "power_mw": 0.6, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "SNOWTWN1", "power_mw": 85.3684, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "SNOWSTH1", "power_mw": 120.4, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "SNOWNTH1", "power_mw": 126.4, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "SMTHBES1L1", "power_mw": 0.0515, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "SMTHBES1", "power_mw": -0.0515, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "STAN-2", "power_mw": 161.4402, "emissions_tco2e": 11.4723, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "TARONG#2", "power_mw": 300.6, "emissions_tco2e": 22.1256, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "TARONG#3", "power_mw": 237.4, "emissions_tco2e": 17.0112, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "TARONG#4", "power_mw": 237.3, "emissions_tco2e": 17.026, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "VBB1", "power_mw": 6.8, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "ULPBESSG1", "power_mw": 2.789, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "ULPBESS1", "power_mw": 2.789, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "TUNGATIN", "power_mw": 97.08, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "TULLYSM1", "power_mw": 10.2, "emissions_tco2e": 0.0154, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "TRIBUTE", "power_mw": 48.02, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "TREVALLN", "power_mw": 5.16, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "TORRB4", "power_mw": 43.0, "emissions_tco2e": 1.9913, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "TNPS1", "power_mw": 281.5, "emissions_tco2e": 19.6886, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "TIBG1", "power_mw": 3.23, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "TIB1", "power_mw": 3.23, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "TB2SF1", "power_mw": 0.0, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "TB2BL1", "power_mw": 0.0815, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "TB2B1", "power_mw": 0.0815, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "TARRALEA", "power_mw": 59.8, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "VP6", "power_mw": 400.8911, "emissions_tco2e": 36.1577, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "LOYYB1", "power_mw": 403.5, "emissions_tco2e": 37.071, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CLERMSF1", "power_mw": 15.6, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CLEMGPWF", "power_mw": 53.0178, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CLARESF1", "power_mw": 9.6097, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CHYTWF1", "power_mw": 12.61, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CHBESSG1", "power_mw": 0.4979, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CHBESS1", "power_mw": 0.4979, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CHALLHWF", "power_mw": 23.4, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CLRKCWF1", "power_mw": 62.6688, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CBWWBA1G", "power_mw": 0.049, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CBWWBA1", "power_mw": 0.049, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CATHROCK", "power_mw": 41.0, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CAPTL_WF", "power_mw": 114.3572, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CAPBES1G", "power_mw": 63.98, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CAPBES1", "power_mw": 63.98, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CALL_B_2", "power_mw": 299.9, "emissions_tco2e": 23.0976, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CALL_B_1", "power_mw": 280.3, "emissions_tco2e": 21.3975, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "BW03", "power_mw": 550.1671, "emissions_tco2e": 42.1587, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "BW02", "power_mw": 542.0371, "emissions_tco2e": 41.8221, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CETHANA", "power_mw": 57.709, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CLRKCWF2", "power_mw": 16.8622, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CNUNDAWF", "power_mw": 43.4507, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "DEVILS_G", "power_mw": 24.0266, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "DDSF1", "power_mw": 13.1569, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "DAYDSF1", "power_mw": 24.155, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "DARLSF1", "power_mw": 26.8358, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "DALNTH1", "power_mw": 0.1114, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "DALNTH01", "power_mw": 0.1114, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CULLRGWF", "power_mw": 24.79, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CTHLWF1", "power_mw": 32.2057, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CSPVPS1", "power_mw": 3.4, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CLUNY", "power_mw": 19.778, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CRWASF1", "power_mw": 1.3174, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CROWLWF1", "power_mw": 54.1778, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CROOKWF3", "power_mw": 37.3082, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CROOKWF2", "power_mw": 57.6944, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CPP_4", "power_mw": 402.05, "emissions_tco2e": 29.5963, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "COOPGWF1", "power_mw": 309.91, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CONDONG1", "power_mw": 23.49, "emissions_tco2e": 0.0703, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "COLWF01", "power_mw": 137.2946, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "COLUMSF1", "power_mw": 25.122, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "COLEASF1", "power_mw": 30.0996, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "COHUNSF1", "power_mw": 0.07, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "CRURWF1", "power_mw": 19.6984, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "BULGANA1", "power_mw": 46.6, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "BULBESG1", "power_mw": 0.33, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "BULBES1", "power_mw": 0.33, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "BBATTERY1", "power_mw": 0.7326, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "BBATTERY", "power_mw": 0.7326, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "BASTYAN", "power_mw": 62.58, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "BARCSF1", "power_mw": 0.8, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "BANN1", "power_mw": 5.56, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "BANGOWF2", "power_mw": 48.4993, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "BANGOWF1", "power_mw": 73.5973, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "AVLSF1", "power_mw": 49.0938, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "ARWF1", "power_mw": 47.4, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "ALDGASF1", "power_mw": 38.0539, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "ADPPV1", "power_mw": 0.172, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "ADPBA1G", "power_mw": 0.133, "emissions_tco2e": 0.0, "hour": 6}
# Received message on topic szha0285/ass2: {"event_timestamp": "2025-10-01T06:40:00+10:00", "facility_code": "ADPBA1", "power_mw": 0.133, "emissions_tco2e": 0.0, "hour": 6}

# %%
# Load and Prepare Data

# Load facility and market data
df_facility = pd.read_csv('nem_data_output/nem_facility_data.csv')
df_market = pd.read_csv('nem_data_output/nem_market_data.csv')

# Convert timestamp to datetime for proper sorting
df_facility['timestamp'] = pd.to_datetime(df_facility['timestamp'])
df_market['timestamp'] = pd.to_datetime(df_market['timestamp'])

print(f"\n Loaded facility data: {len(df_facility):,} records")
print(f" Loaded market data: {len(df_market):,} records")
# Out:
#  Loaded facility data: 1,120,059 records
#  Loaded market data: 11,490 records

# %%
# Sort by Event Time (Chronological Order)

# Sort by timestamp to ensure chronological event order
df_filtered = df_facility.sort_values('timestamp').reset_index(drop=True)

print("✓ Data sorted by event timestamp")
print(f"  Event time range: {df_filtered['timestamp'].min()} to {df_filtered['timestamp'].max()}")
print(f"  Time span: {(df_filtered['timestamp'].max() - df_filtered['timestamp'].min()).total_seconds() / 3600:.1f} hours")
print(f"  Unique facilities: {df_filtered['facility_code'].nunique()}")
print()
# Out:
# ✓ Data sorted by event timestamp
#   Event time range: 2025-10-01 00:00:00+10:00 to 2025-10-08 23:50:00+10:00
#   Time span: 191.8 hours
#   Unique facilities: 533

# %%
# Sample Message Display

print("First 5 records to be published:")
sample_df = df_filtered[['timestamp', 'facility_code', 'power', 'emissions']].head(5)
print(sample_df.to_string(index=False))
print()

print("JSON message format (example):")
sample_row = df_filtered.iloc[0]
sample_message = {
    "event_timestamp": sample_row['timestamp'].isoformat(),
    "facility_code": sample_row['facility_code'],
    "power_mw": float(sample_row['power']),
    "emissions_tco2e": float(sample_row['emissions']),
    "hour": int(sample_row['hour'])
}
print(json.dumps(sample_message, indent=2))
print()
# Out:
# First 5 records to be published:
#                 timestamp facility_code   power  emissions
# 2025-10-01 00:00:00+10:00        ADPBA1 -0.0040        0.0
# 2025-10-01 00:00:00+10:00        QBYNB1 -0.1765        0.0
# 2025-10-01 00:00:00+10:00         PUMP2  0.0000        0.0
# 2025-10-01 00:00:00+10:00         PUMP1  0.0000        0.0
# 2025-10-01 00:00:00+10:00       PTSTAN1  0.0000        0.0
#
# JSON message format (example):
# {
#   "event_timestamp": "2025-10-01T00:00:00+10:00",
#   "facility_code": "ADPBA1",
#   "power_mw": -0.004,
#   "emissions_tco2e": 0.0,
#   "hour": 0
# }

# %%
# Publishing Function

def publish_facility_stream(df, topic, delay=0.1, restart_delay=60):
    """
    Publish facility power and emissions data as a continuous stream.
    Only publishes NEW records (records where power or emissions changed from last value).
    
    Args:
        df: DataFrame with facility data sorted by event timestamp
        topic: MQTT topic to publish to
        delay: Delay between messages in seconds (exactly 0.1s)
        restart_delay: Delay before restarting replay (60s)
    """
    
    total_records = len(df)
    cumulative_published = 0
    cumulative_skipped = 0
    replay_count = 0
    
    print("\n" + "=" * 70)
    print("MQTT STREAM PUBLISHING STARTED")
    print("=" * 70)
    print(f"Total records per replay: {total_records:,}")
    print(f"Message delay: {delay}s (exactly 0.1 second)")
    print(f"Restart delay: {restart_delay}s (when data exhausted)")
    print(f"Publishing strategy: Only NEW records (changed values)")
    print(f"MQTT topic: {topic}")
    print(f"MQTT broker: {BROKER_HOST}:{BROKER_PORT}")
    print(f"Event time range: {df['timestamp'].min()} to {df['timestamp'].max()}")
    print("=" * 70 + "\n")
    
    print("Stream publishing in progress...")
    print("(Press Ctrl+C to stop)\n")
    
    try:
        while True:  # Infinite loop for continuous replay
            replay_count += 1
            replay_start_time = time.time()
            replay_published = 0
            replay_skipped = 0
            
            # Track last values per facility to detect changes
            last_values = {}  # facility_code: (power, emissions)
            
            print("_" * 70)
            print(f"REPLAY #{replay_count} - Started at {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
            print("_" * 70 + "\n")
            
            # Publish each record in chronological order
            for idx, row in df.iterrows():
                # Get current values
                current_power = float(row['power'])
                current_emissions = float(row['emissions'])
                facility_code = row['facility_code']
                
                # Check if this is a NEW record (changed from last value)
                should_publish = True
                
                if facility_code in last_values:
                    last_power, last_emissions = last_values[facility_code]
                    # Skip if BOTH power AND emissions are unchanged
                    if last_power == current_power and last_emissions == current_emissions:
                        should_publish = False
                        replay_skipped += 1
                        cumulative_skipped += 1
                
                # Update last values for this facility
                last_values[facility_code] = (current_power, current_emissions)
                
                if not should_publish:
                    continue
                
                # Create message payload with ALL necessary information
                message = {
                    "event_timestamp": row['timestamp'].isoformat(),
                    "facility_code": row['facility_code'],
                    "power_mw": current_power,
                    "emissions_tco2e": current_emissions,
                    "hour": int(row['hour'])
                }
                
                # Convert to JSON
                message_json = json.dumps(message)
                
                # Publish to MQTT broker
                result = client.publish(topic, message_json, qos=0)
                
                # Check if publish was successful
                if result.rc != mqtt.MQTT_ERR_SUCCESS:
                    print(f"! Warning: Publish failed with code {result.rc}")
                
                replay_published += 1
                cumulative_published += 1
                
                # Progress reporting every 500 messages
                if replay_published % 500 == 0:
                    progress_pct = ((idx + 1) / total_records) * 100
                    elapsed = time.time() - replay_start_time
                    rate = replay_published / elapsed if elapsed > 0 else 0
                    
                    print(f"{datetime.now().strftime('%H:%M:%S')} | "
                          f"Progress: {idx + 1:,}/{total_records:,} ({progress_pct:.1f}%) | "
                          f"Published: {replay_published:,} | "
                          f"Skipped: {replay_skipped:,} | "
                          f"Rate: {rate:.1f} msg/s")
                
                # EXACTLY 0.1 second delay between messages
                time.sleep(delay)
            
            # Replay completed
            replay_duration = time.time() - replay_start_time
            
            print("\n" + "=" * 70)
            print(f"REPLAY #{replay_count} COMPLETED")
            print("=" * 70)
            print(f"Total records processed: {total_records:,}")
            print(f"Records published (new): {replay_published:,}")
            print(f"Records skipped (unchanged): {replay_skipped:,}")
            print(f"New record rate: {(replay_published/total_records)*100:.1f}%")
            print(f"Replay duration: {replay_duration:.1f}s")
            print(f"Cumulative total published: {cumulative_published:,} messages")
            print(f"Cumulative total skipped: {cumulative_skipped:,} messages")
            print(f"Waiting {restart_delay}s before next replay...")
            print("=" * 70 + "\n")
            
            # Wait 60 seconds before restarting
            time.sleep(restart_delay)
    
    except KeyboardInterrupt:
        print("\n\n" + "=" * 70)
        print("STREAM PUBLISHING STOPPED BY USER")
        print("=" * 70)
        print(f"Total replays completed: {replay_count}")
        print(f"Total messages published: {cumulative_published:,}")
        print(f"Total messages skipped: {cumulative_skipped:,}")
        print("=" * 70 + "\n")
    
    except Exception as e:
        print(f"\n\n✗ ERROR DURING PUBLISHING: {e}")
        print("=" * 70 + "\n")
        raise
    
    finally:
        print("Cleaning up MQTT connection...")
        client.loop_stop()
        client.disconnect()

# %%
# Start the continuous stream
publish_facility_stream(
    df=df_filtered,
    topic=MQTT_TOPIC,
    delay=0.1,          # Exactly 0.1 second between messages
    restart_delay=60    # 60 second delay before replay
)
# Out:
# ======================================================================
# MQTT STREAM PUBLISHING STARTED
# ======================================================================
# Total records per replay: 1,120,059
# Message delay: 0.1s (exactly 0.1 second)
# Restart delay: 60s (when data exhausted)
# Publishing strategy: Only NEW records (changed values)
# MQTT topic: szha0285/ass2
# MQTT broker: 172.17.34.107:1883
# Event time range: 2025-10-01 00:00:00+10:00 to 2025-10-08 23:50:00+10:00
# ======================================================================
#
# Stream publishing in progress...
# (Press Ctrl+C to stop)
#
# ______________________________________________________________________
# REPLAY #1 - Started at 2025-11-06 18:41:52
# ______________________________________________________________________
#
# 18:42:44 | Progress: 530/1,120,059 (0.0%) | Published: 500 | Skipped: 30 | Rate: 9.7 msg/s
# 18:43:34 | Progress: 1,610/1,120,059 (0.1%) | Published: 1,000 | Skipped: 610 | Rate: 9.8 msg/s
# 18:44:25 | Progress: 2,689/1,120,059 (0.2%) | Published: 1,500 | Skipped: 1,189 | Rate: 9.8 msg/s
# 18:45:15 | Progress: 3,814/1,120,059 (0.3%) | Published: 2,000 | Skipped: 1,814 | Rate: 9.9 msg/s
# 18:46:05 | Progress: 4,877/1,120,059 (0.4%) | Published: 2,500 | Skipped: 2,377 | Rate: 9.9 msg/s
# 18:46:56 | Progress: 5,954/1,120,059 (0.5%) | Published: 3,000 | Skipped: 2,954 | Rate: 9.9 msg/s
# 18:47:46 | Progress: 7,044/1,120,059 (0.6%) | Published: 3,500 | Skipped: 3,544 | Rate: 9.9 msg/s
# 18:48:37 | Progress: 8,145/1,120,059 (0.7%) | Published: 4,000 | Skipped: 4,145 | Rate: 9.9 msg/s
# 18:49:27 | Progress: 9,223/1,120,059 (0.8%) | Published: 4,500 | Skipped: 4,723 | Rate: 9.9 msg/s
# 18:50:18 | Progress: 10,300/1,120,059 (0.9%) | Published: 5,000 | Skipped: 5,300 | Rate: 9.9 msg/s
# 18:51:09 | Progress: 11,381/1,120,059 (1.0%) | Published: 5,500 | Skipped: 5,881 | Rate: 9.9 msg/s
# 18:51:59 | Progress: 12,517/1,120,059 (1.1%) | Published: 6,000 | Skipped: 6,517 | Rate: 9.9 msg/s
# 18:52:50 | Progress: 13,603/1,120,059 (1.2%) | Published: 6,500 | Skipped: 7,103 | Rate: 9.9 msg/s
# 18:53:40 | Progress: 14,710/1,120,059 (1.3%) | Published: 7,000 | Skipped: 7,710 | Rate: 9.9 msg/s
# 18:54:31 | Progress: 15,805/1,120,059 (1.4%) | Published: 7,500 | Skipped: 8,305 | Rate: 9.9 msg/s
# 18:55:21 | Progress: 16,945/1,120,059 (1.5%) | Published: 8,000 | Skipped: 8,945 | Rate: 9.9 msg/s
# 18:56:12 | Progress: 18,084/1,120,059 (1.6%) | Published: 8,500 | Skipped: 9,584 | Rate: 9.9 msg/s
# 18:57:02 | Progress: 19,225/1,120,059 (1.7%) | Published: 9,000 | Skipped: 10,225 | Rate: 9.9 msg/s
# 18:57:53 | Progress: 20,398/1,120,059 (1.8%) | Published: 9,500 | Skipped: 10,898 | Rate: 9.9 msg/s
# 18:58:43 | Progress: 21,535/1,120,059 (1.9%) | Published: 10,000 | Skipped: 11,535 | Rate: 9.9 msg/s
# 18:59:34 | Progress: 22,688/1,120,059 (2.0%) | Published: 10,500 | Skipped: 12,188 | Rate: 9.9 msg/s
# 19:00:24 | Progress: 23,806/1,120,059 (2.1%) | Published: 11,000 | Skipped: 12,806 | Rate: 9.9 msg/s
# 19:01:15 | Progress: 24,894/1,120,059 (2.2%) | Published: 11,500 | Skipped: 13,394 | Rate: 9.9 msg/s
# 19:02:05 | Progress: 26,022/1,120,059 (2.3%) | Published: 12,000 | Skipped: 14,022 | Rate: 9.9 msg/s
# 19:02:56 | Progress: 27,179/1,120,059 (2.4%) | Published: 12,500 | Skipped: 14,679 | Rate: 9.9 msg/s
# 19:03:46 | Progress: 28,306/1,120,059 (2.5%) | Published: 13,000 | Skipped: 15,306 | Rate: 9.9 msg/s
# 19:04:37 | Progress: 29,467/1,120,059 (2.6%) | Published: 13,500 | Skipped: 15,967 | Rate: 9.9 msg/s
# 19:05:27 | Progress: 30,625/1,120,059 (2.7%) | Published: 14,000 | Skipped: 16,625 | Rate: 9.9 msg/s
# 19:06:18 | Progress: 31,760/1,120,059 (2.8%) | Published: 14,500 | Skipped: 17,260 | Rate: 9.9 msg/s
# 19:07:08 | Progress: 32,844/1,120,059 (2.9%) | Published: 15,000 | Skipped: 17,844 | Rate: 9.9 msg/s
# 19:07:59 | Progress: 33,932/1,120,059 (3.0%) | Published: 15,500 | Skipped: 18,432 | Rate: 9.9 msg/s
# 19:08:49 | Progress: 34,968/1,120,059 (3.1%) | Published: 16,000 | Skipped: 18,968 | Rate: 9.9 msg/s
# 19:09:40 | Progress: 35,893/1,120,059 (3.2%) | Published: 16,500 | Skipped: 19,393 | Rate: 9.9 msg/s
# 19:10:30 | Progress: 36,759/1,120,059 (3.3%) | Published: 17,000 | Skipped: 19,759 | Rate: 9.9 msg/s
# 19:11:21 | Progress: 37,591/1,120,059 (3.4%) | Published: 17,500 | Skipped: 20,091 | Rate: 9.9 msg/s
# 19:12:12 | Progress: 38,332/1,120,059 (3.4%) | Published: 18,000 | Skipped: 20,332 | Rate: 9.9 msg/s
